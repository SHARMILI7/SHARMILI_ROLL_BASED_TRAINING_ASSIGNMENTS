# %%
# !pip install pyspark

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("EcommerceProject").getOrCreate()

# %%
customers_csv = """customer_id,name,city,age,signup_date
1,Amit,Hyderabad,28,2023-01-10
2,Priya,Bangalore,32,2023-02-12
3,Rahul,Mumbai,29,2023-03-14
4,Sneha,Delhi,35,2023-04-15
5,Arjun,Chennai,27,2023-05-11
6,Meera,Hyderabad,31,2023-06-10
7,Karan,Pune,33,2023-06-22
8,Neha,Delhi,30,2023-07-10
9,Divya,Bangalore,26,2023-07-15
10,Vikram,Mumbai,40,2023-08-01
11,Ritu,Hyderabad,34,2023-08-10
12,Sanjay,Delhi,38,2023-08-21
13,Naveen,Chennai,28,2023-09-01
14,Farhan,Mumbai,36,2023-09-10
15,Simran,Bangalore,25,2023-09-18
"""

# %%
products_csv = """product_id,product_name,category,price
101,Laptop,Electronics,75000
102,Headphones,Electronics,3000
103,Keyboard,Electronics,1500
104,Monitor,Electronics,12000
105,Office Chair,Furniture,7000
106,Desk,Furniture,15000
107,Smartphone,Electronics,40000
108,Notebook,Stationery,100
109,Pen,Stationery,20
110,Tablet,Electronics,30000
"""

# %%
orders_csv = """order_id,customer_id,order_date,status
1,1,2024-03-01,Delivered
2,2,2024-03-02,Delivered
3,3,2024-03-03,Cancelled
4,4,2024-03-04,Delivered
5,5,2024-03-05,Delivered
6,6,2024-03-06,Delivered
7,7,2024-03-07,Pending
8,8,2024-03-08,Delivered
9,9,2024-03-09,Delivered
10,10,2024-03-10,Delivered
"""

# %%
order_items_csv = """order_id,product_id,quantity
1,101,1
1,102,2
2,103,1
3,101,1
4,104,1
5,107,1
6,102,3
7,103,2
8,110,1
9,108,5
10,109,10
"""

# %%
payments_csv = """payment_id,order_id,payment_type,amount

1,1,Credit Card,81000
2,2,UPI,1500
3,3,Debit Card,75000
4,4,Credit Card,12000
5,5,UPI,40000
6,6,UPI,9000
7,7,Debit Card,3000
8,8,Credit Card,30000
9,9,UPI,500
10,10,UPI,200
"""

# %%
logs_txt = """login Amit
login Priya
view Rahul
purchase Amit
view Sneha
login Amit
purchase Priya
view Arjun
purchase Sneha
login Rahul
logout Amit
login Neha
purchase Neha
view Vikram
purchase Vikram
login Farhan
view Farhan
purchase Farhan
login Simran
purchase Simran
"""

# %%
with open("customers.csv","w") as f:
    f.write(customers_csv)

with open("products.csv","w") as f:
    f.write(products_csv)

with open("orders.csv","w") as f:
    f.write(orders_csv)

with open("order_items.csv","w") as f:
    f.write(order_items_csv)

with open("payments.csv","w") as f:
    f.write(payments_csv)

with open("logs.txt","w") as f:
    f.write(logs_txt)

# %%
customers = spark.read.csv("customers.csv", header=True, inferSchema=True)
products = spark.read.csv("products.csv", header=True, inferSchema=True)
orders = spark.read.csv("orders.csv", header=True, inferSchema=True)
order_items = spark.read.csv("order_items.csv", header=True, inferSchema=True)
payments = spark.read.csv("payments.csv", header=True, inferSchema=True)

# %% [markdown]
# **SECTION** -**1**

# %%
customers.show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |          1|  Amit|Hyderabad| 28| 2023-01-10|
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          3| Rahul|   Mumbai| 29| 2023-03-14|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |          5| Arjun|  Chennai| 27| 2023-05-11|
# |          6| Meera|Hyderabad| 31| 2023-06-10|
# |          7| Karan|     Pune| 33| 2023-06-22|
# |          8|  Neha|    Delhi| 30| 2023-07-10|
# |          9| Divya|Bangalore| 26| 2023-07-15|
# |         10|Vikram|   Mumbai| 40| 2023-08-01|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|
# |         13|Naveen|  Chennai| 28| 2023-09-01|
# |         14|Farhan|   Mumbai| 36| 2023-09-10|
# |         15|Simran|Bangalore| 25| 2023-09-18|
# +-----------+------+---------+---+-----------+

# %%
customers.printSchema()
# Out:
# root
#  |-- customer_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- signup_date: date (nullable = true)

# %%
customers.count()
# Out:
# 15

# %%
customers.show(5)
# Out:
# +-----------+-----+---------+---+-----------+
# |customer_id| name|     city|age|signup_date|
# +-----------+-----+---------+---+-----------+
# |          1| Amit|Hyderabad| 28| 2023-01-10|
# |          2|Priya|Bangalore| 32| 2023-02-12|
# |          3|Rahul|   Mumbai| 29| 2023-03-14|
# |          4|Sneha|    Delhi| 35| 2023-04-15|
# |          5|Arjun|  Chennai| 27| 2023-05-11|
# +-----------+-----+---------+---+-----------+
# only showing top 5 rows

# %%
customers.select("name","city").show()
# Out:
# +------+---------+
# |  name|     city|
# +------+---------+
# |  Amit|Hyderabad|
# | Priya|Bangalore|
# | Rahul|   Mumbai|
# | Sneha|    Delhi|
# | Arjun|  Chennai|
# | Meera|Hyderabad|
# | Karan|     Pune|
# |  Neha|    Delhi|
# | Divya|Bangalore|
# |Vikram|   Mumbai|
# |  Ritu|Hyderabad|
# |Sanjay|    Delhi|
# |Naveen|  Chennai|
# |Farhan|   Mumbai|
# |Simran|Bangalore|
# +------+---------+

# %%
products.count()
# Out:
# 10

# %%
products.select("product_name","price").show()
# Out:
# +------------+-----+
# |product_name|price|
# +------------+-----+
# |      Laptop|75000|
# |  Headphones| 3000|
# |    Keyboard| 1500|
# |     Monitor|12000|
# |Office Chair| 7000|
# |        Desk|15000|
# |  Smartphone|40000|
# |    Notebook|  100|
# |         Pen|   20|
# |      Tablet|30000|
# +------------+-----+

# %%
orders.show()
# Out:
# +--------+-----------+----------+---------+
# |order_id|customer_id|order_date|   status|
# +--------+-----------+----------+---------+
# |       1|          1|2024-03-01|Delivered|
# |       2|          2|2024-03-02|Delivered|
# |       3|          3|2024-03-03|Cancelled|
# |       4|          4|2024-03-04|Delivered|
# |       5|          5|2024-03-05|Delivered|
# |       6|          6|2024-03-06|Delivered|
# |       7|          7|2024-03-07|  Pending|
# |       8|          8|2024-03-08|Delivered|
# |       9|          9|2024-03-09|Delivered|
# |      10|         10|2024-03-10|Delivered|
# +--------+-----------+----------+---------+

# %%
orders.count()
# Out:
# 10

# %%
payments.show()
# Out:
# +----------+--------+------------+------+
# |payment_id|order_id|payment_type|amount|
# +----------+--------+------------+------+
# |         1|       1| Credit Card| 81000|
# |         2|       2|         UPI|  1500|
# |         3|       3|  Debit Card| 75000|
# |         4|       4| Credit Card| 12000|
# |         5|       5|         UPI| 40000|
# |         6|       6|         UPI|  9000|
# |         7|       7|  Debit Card|  3000|
# |         8|       8| Credit Card| 30000|
# |         9|       9|         UPI|   500|
# |        10|      10|         UPI|   200|
# +----------+--------+------------+------+

# %%
customers.filter(customers.city=="Hyderabad").show()
# Out:
# +-----------+-----+---------+---+-----------+
# |customer_id| name|     city|age|signup_date|
# +-----------+-----+---------+---+-----------+
# |          1| Amit|Hyderabad| 28| 2023-01-10|
# |          6|Meera|Hyderabad| 31| 2023-06-10|
# |         11| Ritu|Hyderabad| 34| 2023-08-10|
# +-----------+-----+---------+---+-----------+

# %%
customers.filter(customers.age>30).show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |          6| Meera|Hyderabad| 31| 2023-06-10|
# |          7| Karan|     Pune| 33| 2023-06-22|
# |         10|Vikram|   Mumbai| 40| 2023-08-01|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|
# |         14|Farhan|   Mumbai| 36| 2023-09-10|
# +-----------+------+---------+---+-----------+

# %%
products.filter(products.price>10000).show()
# Out:
# +----------+------------+-----------+-----+
# |product_id|product_name|   category|price|
# +----------+------------+-----------+-----+
# |       101|      Laptop|Electronics|75000|
# |       104|     Monitor|Electronics|12000|
# |       106|        Desk|  Furniture|15000|
# |       107|  Smartphone|Electronics|40000|
# |       110|      Tablet|Electronics|30000|
# +----------+------------+-----------+-----+

# %%
products.filter(products.category=="Electronics").show()
# Out:
# +----------+------------+-----------+-----+
# |product_id|product_name|   category|price|
# +----------+------------+-----------+-----+
# |       101|      Laptop|Electronics|75000|
# |       102|  Headphones|Electronics| 3000|
# |       103|    Keyboard|Electronics| 1500|
# |       104|     Monitor|Electronics|12000|
# |       107|  Smartphone|Electronics|40000|
# |       110|      Tablet|Electronics|30000|
# +----------+------------+-----------+-----+

# %%
orders.filter(orders.status=="Deliverd").show()
# Out:
# +--------+-----------+----------+------+
# |order_id|customer_id|order_date|status|
# +--------+-----------+----------+------+
# +--------+-----------+----------+------+

# %%
orders.filter(orders.status=="Cancelled").show()
# Out:
# +--------+-----------+----------+---------+
# |order_id|customer_id|order_date|   status|
# +--------+-----------+----------+---------+
# |       3|          3|2024-03-03|Cancelled|
# +--------+-----------+----------+---------+

# %%
payments.filter(payments.payment_type=="UPI").show()
# Out:
# +----------+--------+------------+------+
# |payment_id|order_id|payment_type|amount|
# +----------+--------+------------+------+
# |         2|       2|         UPI|  1500|
# |         5|       5|         UPI| 40000|
# |         6|       6|         UPI|  9000|
# |         9|       9|         UPI|   500|
# |        10|      10|         UPI|   200|
# +----------+--------+------------+------+

# %%
customers.filter((customers.city=="Bangalore")|(customers.city=="Delhi")).show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |          8|  Neha|    Delhi| 30| 2023-07-10|
# |          9| Divya|Bangalore| 26| 2023-07-15|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|
# |         15|Simran|Bangalore| 25| 2023-09-18|
# +-----------+------+---------+---+-----------+

# %%
products.filter(products.price<1000).show()
# Out:
# +----------+------------+----------+-----+
# |product_id|product_name|  category|price|
# +----------+------------+----------+-----+
# |       108|    Notebook|Stationery|  100|
# |       109|         Pen|Stationery|   20|
# +----------+------------+----------+-----+

# %%
customers.filter((customers.age>=25)&(customers.age<=35)).show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |          1|  Amit|Hyderabad| 28| 2023-01-10|
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          3| Rahul|   Mumbai| 29| 2023-03-14|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |          5| Arjun|  Chennai| 27| 2023-05-11|
# |          6| Meera|Hyderabad| 31| 2023-06-10|
# |          7| Karan|     Pune| 33| 2023-06-22|
# |          8|  Neha|    Delhi| 30| 2023-07-10|
# |          9| Divya|Bangalore| 26| 2023-07-15|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|
# |         13|Naveen|  Chennai| 28| 2023-09-01|
# |         15|Simran|Bangalore| 25| 2023-09-18|
# +-----------+------+---------+---+-----------+

# %%
products=products.withColumnRenamed("price","product_price")
products.show()
# Out:
# +----------+------------+-----------+-------------+
# |product_id|product_name|   category|product_price|
# +----------+------------+-----------+-------------+
# |       101|      Laptop|Electronics|        75000|
# |       102|  Headphones|Electronics|         3000|
# |       103|    Keyboard|Electronics|         1500|
# |       104|     Monitor|Electronics|        12000|
# |       105|Office Chair|  Furniture|         7000|
# |       106|        Desk|  Furniture|        15000|
# |       107|  Smartphone|Electronics|        40000|
# |       108|    Notebook| Stationery|          100|
# |       109|         Pen| Stationery|           20|
# |       110|      Tablet|Electronics|        30000|
# +----------+------------+-----------+-------------+

# %%
customers=customers.withColumnRenamed("name","customer_name")
customers.show()
# Out:
# +-----------+-------------+---------+---+-----------+
# |customer_id|customer_name|     city|age|signup_date|
# +-----------+-------------+---------+---+-----------+
# |          1|         Amit|Hyderabad| 28| 2023-01-10|
# |          2|        Priya|Bangalore| 32| 2023-02-12|
# |          3|        Rahul|   Mumbai| 29| 2023-03-14|
# |          4|        Sneha|    Delhi| 35| 2023-04-15|
# |          5|        Arjun|  Chennai| 27| 2023-05-11|
# |          6|        Meera|Hyderabad| 31| 2023-06-10|
# |          7|        Karan|     Pune| 33| 2023-06-22|
# |          8|         Neha|    Delhi| 30| 2023-07-10|
# |          9|        Divya|Bangalore| 26| 2023-07-15|
# |         10|       Vikram|   Mumbai| 40| 2023-08-01|
# |         11|         Ritu|Hyderabad| 34| 2023-08-10|
# |         12|       Sanjay|    Delhi| 38| 2023-08-21|
# |         13|       Naveen|  Chennai| 28| 2023-09-01|
# |         14|       Farhan|   Mumbai| 36| 2023-09-10|
# ...

# %%
customers.select("customer_name","age").show()
# Out:
# +-------------+---+
# |customer_name|age|
# +-------------+---+
# |         Amit| 28|
# |        Priya| 32|
# |        Rahul| 29|
# |        Sneha| 35|
# |        Arjun| 27|
# |        Meera| 31|
# |        Karan| 33|
# |         Neha| 30|
# |        Divya| 26|
# |       Vikram| 40|
# |         Ritu| 34|
# |       Sanjay| 38|
# |       Naveen| 28|
# |       Farhan| 36|
# |       Simran| 25|
# +-------------+---+

# %%
products.select("product_name","category").show()
# Out:
# +------------+-----------+
# |product_name|   category|
# +------------+-----------+
# |      Laptop|Electronics|
# |  Headphones|Electronics|
# |    Keyboard|Electronics|
# |     Monitor|Electronics|
# |Office Chair|  Furniture|
# |        Desk|  Furniture|
# |  Smartphone|Electronics|
# |    Notebook| Stationery|
# |         Pen| Stationery|
# |      Tablet|Electronics|
# +------------+-----------+

# %%
orders.select("order_id","order_date").show()
# Out:
# +--------+----------+
# |order_id|order_date|
# +--------+----------+
# |       1|2024-03-01|
# |       2|2024-03-02|
# |       3|2024-03-03|
# |       4|2024-03-04|
# |       5|2024-03-05|
# |       6|2024-03-06|
# |       7|2024-03-07|
# |       8|2024-03-08|
# |       9|2024-03-09|
# |      10|2024-03-10|
# +--------+----------+

# %%
payments.select("payment_type","amount").show()
# Out:
# +------------+------+
# |payment_type|amount|
# +------------+------+
# | Credit Card| 81000|
# |         UPI|  1500|
# |  Debit Card| 75000|
# | Credit Card| 12000|
# |         UPI| 40000|
# |         UPI|  9000|
# |  Debit Card|  3000|
# | Credit Card| 30000|
# |         UPI|   500|
# |         UPI|   200|
# +------------+------+

# %%
from pyspark.sql.functions import col
products=products.withColumn("price_in_lakhs",col("product_price"))
products.show()
# Out:
# +----------+------------+-----------+-------------+--------------+
# |product_id|product_name|   category|product_price|price_in_lakhs|
# +----------+------------+-----------+-------------+--------------+
# |       101|      Laptop|Electronics|        75000|         75000|
# |       102|  Headphones|Electronics|         3000|          3000|
# |       103|    Keyboard|Electronics|         1500|          1500|
# |       104|     Monitor|Electronics|        12000|         12000|
# |       105|Office Chair|  Furniture|         7000|          7000|
# |       106|        Desk|  Furniture|        15000|         15000|
# |       107|  Smartphone|Electronics|        40000|         40000|
# |       108|    Notebook| Stationery|          100|           100|
# |       109|         Pen| Stationery|           20|            20|
# |       110|      Tablet|Electronics|        30000|         30000|
# +----------+------------+-----------+-------------+--------------+

# %%
from pyspark.sql.functions import when
customers=customers.withColumn("age_group",when(col("age")<30,"Young").when(col("age")<40,"Adult").otherwise("Senior"))
customers.show()
# Out:
# +-----------+-------------+---------+---+-----------+---------+
# |customer_id|customer_name|     city|age|signup_date|age_group|
# +-----------+-------------+---------+---+-----------+---------+
# |          1|         Amit|Hyderabad| 28| 2023-01-10|    Young|
# |          2|        Priya|Bangalore| 32| 2023-02-12|    Adult|
# |          3|        Rahul|   Mumbai| 29| 2023-03-14|    Young|
# |          4|        Sneha|    Delhi| 35| 2023-04-15|    Adult|
# |          5|        Arjun|  Chennai| 27| 2023-05-11|    Young|
# |          6|        Meera|Hyderabad| 31| 2023-06-10|    Adult|
# |          7|        Karan|     Pune| 33| 2023-06-22|    Adult|
# |          8|         Neha|    Delhi| 30| 2023-07-10|    Adult|
# |          9|        Divya|Bangalore| 26| 2023-07-15|    Young|
# |         10|       Vikram|   Mumbai| 40| 2023-08-01|   Senior|
# |         11|         Ritu|Hyderabad| 34| 2023-08-10|    Adult|
# |         12|       Sanjay|    Delhi| 38| 2023-08-21|    Adult|
# ...

# %%
order_items.filter(col("quantity")>2).show()
# Out:
# +--------+----------+--------+
# |order_id|product_id|quantity|
# +--------+----------+--------+
# |       6|       102|       3|
# |       9|       108|       5|
# |      10|       109|      10|
# +--------+----------+--------+

# %%
customers.orderBy("age").show()
# Out:
# +-----------+-------------+---------+---+-----------+---------+
# |customer_id|customer_name|     city|age|signup_date|age_group|
# +-----------+-------------+---------+---+-----------+---------+
# |         15|       Simran|Bangalore| 25| 2023-09-18|    Young|
# |          9|        Divya|Bangalore| 26| 2023-07-15|    Young|
# |          5|        Arjun|  Chennai| 27| 2023-05-11|    Young|
# |          1|         Amit|Hyderabad| 28| 2023-01-10|    Young|
# |         13|       Naveen|  Chennai| 28| 2023-09-01|    Young|
# |          3|        Rahul|   Mumbai| 29| 2023-03-14|    Young|
# |          8|         Neha|    Delhi| 30| 2023-07-10|    Adult|
# |          6|        Meera|Hyderabad| 31| 2023-06-10|    Adult|
# |          2|        Priya|Bangalore| 32| 2023-02-12|    Adult|
# |          7|        Karan|     Pune| 33| 2023-06-22|    Adult|
# |         11|         Ritu|Hyderabad| 34| 2023-08-10|    Adult|
# |          4|        Sneha|    Delhi| 35| 2023-04-15|    Adult|
# ...

# %%
customers.orderBy("age").show()
# Out:
# +-----------+-------------+---------+---+-----------+---------+
# |customer_id|customer_name|     city|age|signup_date|age_group|
# +-----------+-------------+---------+---+-----------+---------+
# |         15|       Simran|Bangalore| 25| 2023-09-18|    Young|
# |          9|        Divya|Bangalore| 26| 2023-07-15|    Young|
# |          5|        Arjun|  Chennai| 27| 2023-05-11|    Young|
# |          1|         Amit|Hyderabad| 28| 2023-01-10|    Young|
# |         13|       Naveen|  Chennai| 28| 2023-09-01|    Young|
# |          3|        Rahul|   Mumbai| 29| 2023-03-14|    Young|
# |          8|         Neha|    Delhi| 30| 2023-07-10|    Adult|
# |          6|        Meera|Hyderabad| 31| 2023-06-10|    Adult|
# |          2|        Priya|Bangalore| 32| 2023-02-12|    Adult|
# |          7|        Karan|     Pune| 33| 2023-06-22|    Adult|
# |         11|         Ritu|Hyderabad| 34| 2023-08-10|    Adult|
# |          4|        Sneha|    Delhi| 35| 2023-04-15|    Adult|
# ...

# %%
customers.orderBy(customers.age.desc()).show()
# Out:
# +-----------+-------------+---------+---+-----------+---------+
# |customer_id|customer_name|     city|age|signup_date|age_group|
# +-----------+-------------+---------+---+-----------+---------+
# |         10|       Vikram|   Mumbai| 40| 2023-08-01|   Senior|
# |         12|       Sanjay|    Delhi| 38| 2023-08-21|    Adult|
# |         14|       Farhan|   Mumbai| 36| 2023-09-10|    Adult|
# |          4|        Sneha|    Delhi| 35| 2023-04-15|    Adult|
# |         11|         Ritu|Hyderabad| 34| 2023-08-10|    Adult|
# |          7|        Karan|     Pune| 33| 2023-06-22|    Adult|
# |          2|        Priya|Bangalore| 32| 2023-02-12|    Adult|
# |          6|        Meera|Hyderabad| 31| 2023-06-10|    Adult|
# |          8|         Neha|    Delhi| 30| 2023-07-10|    Adult|
# |          3|        Rahul|   Mumbai| 29| 2023-03-14|    Young|
# |          1|         Amit|Hyderabad| 28| 2023-01-10|    Young|
# |         13|       Naveen|  Chennai| 28| 2023-09-01|    Young|
# ...

# %%
products.orderBy(products.product_price.desc()).show(5)
# Out:
# +----------+------------+-----------+-------------+--------------+
# |product_id|product_name|   category|product_price|price_in_lakhs|
# +----------+------------+-----------+-------------+--------------+
# |       101|      Laptop|Electronics|        75000|         75000|
# |       107|  Smartphone|Electronics|        40000|         40000|
# |       110|      Tablet|Electronics|        30000|         30000|
# |       106|        Desk|  Furniture|        15000|         15000|
# |       104|     Monitor|Electronics|        12000|         12000|
# +----------+------------+-----------+-------------+--------------+
# only showing top 5 rows

# %%
products.orderBy("product_price").show(3)
# Out:
# +----------+------------+-----------+-------------+--------------+
# |product_id|product_name|   category|product_price|price_in_lakhs|
# +----------+------------+-----------+-------------+--------------+
# |       109|         Pen| Stationery|           20|            20|
# |       108|    Notebook| Stationery|          100|           100|
# |       103|    Keyboard|Electronics|         1500|          1500|
# +----------+------------+-----------+-------------+--------------+
# only showing top 3 rows

# %%
orders.orderBy("order_date").show()
# Out:
# +--------+-----------+----------+---------+
# |order_id|customer_id|order_date|   status|
# +--------+-----------+----------+---------+
# |       1|          1|2024-03-01|Delivered|
# |       2|          2|2024-03-02|Delivered|
# |       3|          3|2024-03-03|Cancelled|
# |       4|          4|2024-03-04|Delivered|
# |       5|          5|2024-03-05|Delivered|
# |       6|          6|2024-03-06|Delivered|
# |       7|          7|2024-03-07|  Pending|
# |       8|          8|2024-03-08|Delivered|
# |       9|          9|2024-03-09|Delivered|
# |      10|         10|2024-03-10|Delivered|
# +--------+-----------+----------+---------+

# %%
payments.orderBy("amount").show()
# Out:
# +----------+--------+------------+------+
# |payment_id|order_id|payment_type|amount|
# +----------+--------+------------+------+
# |        10|      10|         UPI|   200|
# |         9|       9|         UPI|   500|
# |         2|       2|         UPI|  1500|
# |         7|       7|  Debit Card|  3000|
# |         6|       6|         UPI|  9000|
# |         4|       4| Credit Card| 12000|
# |         8|       8| Credit Card| 30000|
# |         5|       5|         UPI| 40000|
# |         3|       3|  Debit Card| 75000|
# |         1|       1| Credit Card| 81000|
# +----------+--------+------------+------+

# %%
payments.orderBy(payments.amount.desc()).show(3)
# Out:
# +----------+--------+------------+------+
# |payment_id|order_id|payment_type|amount|
# +----------+--------+------------+------+
# |         1|       1| Credit Card| 81000|
# |         3|       3|  Debit Card| 75000|
# |         5|       5|         UPI| 40000|
# +----------+--------+------------+------+
# only showing top 3 rows

# %%
payments.orderBy("amount").show()
# Out:
# +----------+--------+------------+------+
# |payment_id|order_id|payment_type|amount|
# +----------+--------+------------+------+
# |        10|      10|         UPI|   200|
# |         9|       9|         UPI|   500|
# |         2|       2|         UPI|  1500|
# |         7|       7|  Debit Card|  3000|
# |         6|       6|         UPI|  9000|
# |         4|       4| Credit Card| 12000|
# |         8|       8| Credit Card| 30000|
# |         5|       5|         UPI| 40000|
# |         3|       3|  Debit Card| 75000|
# |         1|       1| Credit Card| 81000|
# +----------+--------+------------+------+

# %%
customers.orderBy("city").show()
# Out:
# +-----------+-------------+---------+---+-----------+---------+
# |customer_id|customer_name|     city|age|signup_date|age_group|
# +-----------+-------------+---------+---+-----------+---------+
# |          2|        Priya|Bangalore| 32| 2023-02-12|    Adult|
# |          9|        Divya|Bangalore| 26| 2023-07-15|    Young|
# |         15|       Simran|Bangalore| 25| 2023-09-18|    Young|
# |          5|        Arjun|  Chennai| 27| 2023-05-11|    Young|
# |         13|       Naveen|  Chennai| 28| 2023-09-01|    Young|
# |          4|        Sneha|    Delhi| 35| 2023-04-15|    Adult|
# |          8|         Neha|    Delhi| 30| 2023-07-10|    Adult|
# |         12|       Sanjay|    Delhi| 38| 2023-08-21|    Adult|
# |          1|         Amit|Hyderabad| 28| 2023-01-10|    Young|
# |          6|        Meera|Hyderabad| 31| 2023-06-10|    Adult|
# |         11|         Ritu|Hyderabad| 34| 2023-08-10|    Adult|
# |          3|        Rahul|   Mumbai| 29| 2023-03-14|    Young|
# ...

# %%
products.orderBy("category").show()
# Out:
# +----------+------------+-----------+-------------+--------------+
# |product_id|product_name|   category|product_price|price_in_lakhs|
# +----------+------------+-----------+-------------+--------------+
# |       101|      Laptop|Electronics|        75000|         75000|
# |       102|  Headphones|Electronics|         3000|          3000|
# |       103|    Keyboard|Electronics|         1500|          1500|
# |       104|     Monitor|Electronics|        12000|         12000|
# |       107|  Smartphone|Electronics|        40000|         40000|
# |       110|      Tablet|Electronics|        30000|         30000|
# |       105|Office Chair|  Furniture|         7000|          7000|
# |       106|        Desk|  Furniture|        15000|         15000|
# |       108|    Notebook| Stationery|          100|           100|
# |       109|         Pen| Stationery|           20|            20|
# +----------+------------+-----------+-------------+--------------+

# %%
from pyspark.sql.functions import sum,avg,max,min,count

# %%
payments.select(sum("amount")).show()
# Out:
# +-----------+
# |sum(amount)|
# +-----------+
# |     252200|
# +-----------+

# %%
payments.select(avg("amount")).show()
# Out:
# +-----------+
# |avg(amount)|
# +-----------+
# |    25220.0|
# +-----------+

# %%
payments.select(max("amount")).show()
# Out:
# +-----------+
# |max(amount)|
# +-----------+
# |      81000|
# +-----------+

# %%
payments.select(min("amount")).show()
# Out:
# +-----------+
# |min(amount)|
# +-----------+
# |        200|
# +-----------+

# %%
customers.groupBy("city").count().show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Bangalore|    3|
# |  Chennai|    2|
# |   Mumbai|    3|
# |     Pune|    1|
# |    Delhi|    3|
# |Hyderabad|    3|
# +---------+-----+

# %%
products.groupBy("category").count().show()
# Out:
# +-----------+-----+
# |   category|count|
# +-----------+-----+
# | Stationery|    2|
# |Electronics|    6|
# |  Furniture|    2|
# +-----------+-----+

# %%
products.groupBy("category").agg(avg("product_price").alias("avg_price")).show()
# Out:
# +-----------+------------------+
# |   category|         avg_price|
# +-----------+------------------+
# | Stationery|              60.0|
# |Electronics|26916.666666666668|
# |  Furniture|           11000.0|
# +-----------+------------------+

# %%
order_items.groupBy("product_id").agg(sum("quantity").alias("total_quantity")).show()
# Out:
# +----------+--------------+
# |product_id|total_quantity|
# +----------+--------------+
# |       108|             5|
# |       101|             2|
# |       103|             3|
# |       107|             1|
# |       102|             5|
# |       109|            10|
# |       110|             1|
# |       104|             1|
# +----------+--------------+

# %%
customers.select(avg("age")).show()
# Out:
# +------------------+
# |          avg(age)|
# +------------------+
# |31.466666666666665|
# +------------------+

# %%
orders.count()
# Out:
# 10

# %%
from pyspark.sql.functions import col,sum

# %%
orders_customers=orders.join(customers,"customer_id")
orders_customers.show()
# Out:
# +-----------+--------+----------+---------+-------------+---------+---+-----------+---------+
# |customer_id|order_id|order_date|   status|customer_name|     city|age|signup_date|age_group|
# +-----------+--------+----------+---------+-------------+---------+---+-----------+---------+
# |          1|       1|2024-03-01|Delivered|         Amit|Hyderabad| 28| 2023-01-10|    Young|
# |          2|       2|2024-03-02|Delivered|        Priya|Bangalore| 32| 2023-02-12|    Adult|
# |          3|       3|2024-03-03|Cancelled|        Rahul|   Mumbai| 29| 2023-03-14|    Young|
# |          4|       4|2024-03-04|Delivered|        Sneha|    Delhi| 35| 2023-04-15|    Adult|
# |          5|       5|2024-03-05|Delivered|        Arjun|  Chennai| 27| 2023-05-11|    Young|
# |          6|       6|2024-03-06|Delivered|        Meera|Hyderabad| 31| 2023-06-10|    Adult|
# |          7|       7|2024-03-07|  Pending|        Karan|     Pune| 33| 2023-06-22|    Adult|
# ...

# %%
orders_customers.select("customer_name","status").show()
# Out:
# +-------------+---------+
# |customer_name|   status|
# +-------------+---------+
# |         Amit|Delivered|
# |        Priya|Delivered|
# |        Rahul|Cancelled|
# |        Sneha|Delivered|
# |        Arjun|Delivered|
# |        Meera|Delivered|
# |        Karan|  Pending|
# |         Neha|Delivered|
# |        Divya|Delivered|
# |       Vikram|Delivered|
# +-------------+---------+

# %%
orders_items=orders.join(order_items,"order_id")
orders_items.show()
# Out:
# +--------+-----------+----------+---------+----------+--------+
# |order_id|customer_id|order_date|   status|product_id|quantity|
# +--------+-----------+----------+---------+----------+--------+
# |       1|          1|2024-03-01|Delivered|       102|       2|
# |       1|          1|2024-03-01|Delivered|       101|       1|
# |       2|          2|2024-03-02|Delivered|       103|       1|
# |       3|          3|2024-03-03|Cancelled|       101|       1|
# |       4|          4|2024-03-04|Delivered|       104|       1|
# |       5|          5|2024-03-05|Delivered|       107|       1|
# |       6|          6|2024-03-06|Delivered|       102|       3|
# |       7|          7|2024-03-07|  Pending|       103|       2|
# |       8|          8|2024-03-08|Delivered|       110|       1|
# |       9|          9|2024-03-09|Delivered|       108|       5|
# |      10|         10|2024-03-10|Delivered|       109|      10|
# +--------+-----------+----------+---------+----------+--------+

# %%
items_products=order_items.join(products,"product_id")
items_products.show()
# Out:
# +----------+--------+--------+------------+-----------+-------------+--------------+
# |product_id|order_id|quantity|product_name|   category|product_price|price_in_lakhs|
# +----------+--------+--------+------------+-----------+-------------+--------------+
# |       101|       3|       1|      Laptop|Electronics|        75000|         75000|
# |       101|       1|       1|      Laptop|Electronics|        75000|         75000|
# |       102|       6|       3|  Headphones|Electronics|         3000|          3000|
# |       102|       1|       2|  Headphones|Electronics|         3000|          3000|
# |       103|       7|       2|    Keyboard|Electronics|         1500|          1500|
# |       103|       2|       1|    Keyboard|Electronics|         1500|          1500|
# |       104|       4|       1|     Monitor|Electronics|        12000|         12000|
# |       107|       5|       1|  Smartphone|Electronics|        40000|         40000|
# ...

# %%
items_products=items_products.withColumn("revenue",col("quantity")*col("product_price"))
items_products.show()
# Out:
# +----------+--------+--------+------------+-----------+-------------+--------------+-------+
# |product_id|order_id|quantity|product_name|   category|product_price|price_in_lakhs|revenue|
# +----------+--------+--------+------------+-----------+-------------+--------------+-------+
# |       101|       3|       1|      Laptop|Electronics|        75000|         75000|  75000|
# |       101|       1|       1|      Laptop|Electronics|        75000|         75000|  75000|
# |       102|       6|       3|  Headphones|Electronics|         3000|          3000|   9000|
# |       102|       1|       2|  Headphones|Electronics|         3000|          3000|   6000|
# |       103|       7|       2|    Keyboard|Electronics|         1500|          1500|   3000|
# |       103|       2|       1|    Keyboard|Electronics|         1500|          1500|   1500|
# |       104|       4|       1|     Monitor|Electronics|        12000|         12000|  12000|
# ...

# %%
full_df=orders.join(customers,"customer_id").join(order_items,"order_id").join(products,"product_id")
full_df.show()
# Out:
# +----------+--------+-----------+----------+---------+-------------+---------+---+-----------+---------+--------+------------+-----------+-------------+--------------+
# |product_id|order_id|customer_id|order_date|   status|customer_name|     city|age|signup_date|age_group|quantity|product_name|   category|product_price|price_in_lakhs|
# +----------+--------+-----------+----------+---------+-------------+---------+---+-----------+---------+--------+------------+-----------+-------------+--------------+
# |       102|       1|          1|2024-03-01|Delivered|         Amit|Hyderabad| 28| 2023-01-10|    Young|       2|  Headphones|Electronics|         3000|          3000|
# |       101|       1|          1|2024-03-01|Delivered|         Amit|Hyderabad| 28| 2023-01-10|    Young|       1|      Laptop|Electronics|        75000|         75000|
# ...

# %%
full_df.select("customer_name","product_name","quantity").show()
# Out:
# +-------------+------------+--------+
# |customer_name|product_name|quantity|
# +-------------+------------+--------+
# |         Amit|  Headphones|       2|
# |         Amit|      Laptop|       1|
# |        Priya|    Keyboard|       1|
# |        Rahul|      Laptop|       1|
# |        Sneha|     Monitor|       1|
# |        Arjun|  Smartphone|       1|
# |        Meera|  Headphones|       3|
# |        Karan|    Keyboard|       2|
# |         Neha|      Tablet|       1|
# |        Divya|    Notebook|       5|
# |       Vikram|         Pen|      10|
# +-------------+------------+--------+

# %%
revenue_per_order=full_df.withColumn("revenue",col("quantity")*col("product_price")).groupBy("order_id").agg(sum("revenue").alias("total_revenue"))
revenue_per_order.show()
# Out:
# +--------+-------------+
# |order_id|total_revenue|
# +--------+-------------+
# |       1|        81000|
# |       6|         9000|
# |       3|        75000|
# |       5|        40000|
# |       9|          500|
# |       4|        12000|
# |       8|        30000|
# |       7|         3000|
# |      10|          200|
# |       2|         1500|
# +--------+-------------+

# %%
revenue_per_product=full_df.withColumn("revenue",col("quantity")*col("product_price")).groupBy("product_name").agg(sum("revenue").alias("total_revenue"))
revenue_per_product.show()
# Out:
# +------------+-------------+
# |product_name|total_revenue|
# +------------+-------------+
# |         Pen|          200|
# |      Laptop|       150000|
# |    Notebook|          500|
# |      Tablet|        30000|
# |    Keyboard|         4500|
# |  Smartphone|        40000|
# |     Monitor|        12000|
# |  Headphones|        15000|
# +------------+-------------+

# %%
revenue_per_customer=full_df.withColumn("revenue",col("quantity")*col("product_price")).groupBy("customer_name").agg(sum("revenue").alias("total_revenue"))
revenue_per_customer.show()
# Out:
# +-------------+-------------+
# |customer_name|total_revenue|
# +-------------+-------------+
# |        Divya|          500|
# |        Meera|         9000|
# |        Sneha|        12000|
# |        Priya|         1500|
# |       Vikram|          200|
# |        Rahul|        75000|
# |        Arjun|        40000|
# |         Amit|        81000|
# |         Neha|        30000|
# |        Karan|         3000|
# +-------------+-------------+

# %%
orders.groupBy("customer_id").count().show()
# Out:
# +-----------+-----+
# |customer_id|count|
# +-----------+-----+
# |          1|    1|
# |          6|    1|
# |          3|    1|
# |          5|    1|
# |          9|    1|
# |          4|    1|
# |          8|    1|
# |          7|    1|
# |         10|    1|
# |          2|    1|
# +-----------+-----+

# %%
orders.join(customers,"customer_id").groupBy("city").count().show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Bangalore|    2|
# |  Chennai|    1|
# |   Mumbai|    2|
# |     Pune|    1|
# |    Delhi|    2|
# |Hyderabad|    2|
# +---------+-----+

# %%
from pyspark.sql.functions import col,sum
full_df=orders.join(customers,"customer_id").join(order_items,"order_id").join(products,"product_id")
full_df=full_df.withColumn("revenue",col("quantity")*col("product_price"))

# %%
full_df.groupBy("product_name").agg(sum("revenue").alias("total_revenue")).show()
# Out:
# +------------+-------------+
# |product_name|total_revenue|
# +------------+-------------+
# |         Pen|          200|
# |      Laptop|       150000|
# |    Notebook|          500|
# |      Tablet|        30000|
# |    Keyboard|         4500|
# |  Smartphone|        40000|
# |     Monitor|        12000|
# |  Headphones|        15000|
# +------------+-------------+

# %%
full_df.groupBy("category").agg(sum("revenue").alias("total_revenue")).show()
# Out:
# +-----------+-------------+
# |   category|total_revenue|
# +-----------+-------------+
# | Stationery|          700|
# |Electronics|       251500|
# +-----------+-------------+

# %%
full_df.groupBy("city").agg(sum("revenue").alias("total_revenue")).show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Bangalore|         2000|
# |  Chennai|        40000|
# |   Mumbai|        75200|
# |     Pune|         3000|
# |    Delhi|        42000|
# |Hyderabad|        90000|
# +---------+-------------+

# %%
from pyspark.sql.functions import sum
full_df.groupBy("product_name").agg(sum("quantity").alias("total_quantity")).show()
# Out:
# +------------+--------------+
# |product_name|total_quantity|
# +------------+--------------+
# |         Pen|            10|
# |      Laptop|             2|
# |    Notebook|             5|
# |      Tablet|             1|
# |    Keyboard|             3|
# |  Smartphone|             1|
# |     Monitor|             1|
# |  Headphones|             5|
# +------------+--------------+

# %%
full_df.groupBy("category").agg(sum("quantity").alias("total_quantity")).show()
# Out:
# +-----------+--------------+
# |   category|total_quantity|
# +-----------+--------------+
# | Stationery|            15|
# |Electronics|            13|
# +-----------+--------------+

# %%
full_df.groupBy("customer_name").agg(sum("revenue").alias("total_revenue")).show()
# Out:
# +-------------+-------------+
# |customer_name|total_revenue|
# +-------------+-------------+
# |        Divya|          500|
# |        Meera|         9000|
# |        Sneha|        12000|
# |        Priya|         1500|
# |       Vikram|          200|
# |        Rahul|        75000|
# |        Arjun|        40000|
# |         Amit|        81000|
# |         Neha|        30000|
# |        Karan|         3000|
# +-------------+-------------+

# %%
full_df.groupBy("customer_name").agg(sum("revenue").alias("total_revenue")).orderBy(col("total_revenue").desc()).show(5)
# Out:
# +-------------+-------------+
# |customer_name|total_revenue|
# +-------------+-------------+
# |         Amit|        81000|
# |        Rahul|        75000|
# |        Arjun|        40000|
# |         Neha|        30000|
# |        Sneha|        12000|
# +-------------+-------------+
# only showing top 5 rows

# %%
full_df.groupBy("product_name").agg(sum("revenue").alias("total_revenue")).orderBy(col("total_revenue").desc()).show(3)
# Out:
# +------------+-------------+
# |product_name|total_revenue|
# +------------+-------------+
# |      Laptop|       150000|
# |  Smartphone|        40000|
# |      Tablet|        30000|
# +------------+-------------+
# only showing top 3 rows

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import rank,dense_rank,row_number,sum,col

# %%
windowSpec=Window.orderBy(col("product_price").desc())
products.withColumn("rank",rank().over(windowSpec)).show()
# Out:
# +----------+------------+-----------+-------------+--------------+----+
# |product_id|product_name|   category|product_price|price_in_lakhs|rank|
# +----------+------------+-----------+-------------+--------------+----+
# |       101|      Laptop|Electronics|        75000|         75000|   1|
# |       107|  Smartphone|Electronics|        40000|         40000|   2|
# |       110|      Tablet|Electronics|        30000|         30000|   3|
# |       106|        Desk|  Furniture|        15000|         15000|   4|
# |       104|     Monitor|Electronics|        12000|         12000|   5|
# |       105|Office Chair|  Furniture|         7000|          7000|   6|
# |       102|  Headphones|Electronics|         3000|          3000|   7|
# |       103|    Keyboard|Electronics|         1500|          1500|   8|
# |       108|    Notebook| Stationery|          100|           100|   9|
# |       109|         Pen| Stationery|           20|            20|  10|
# ...

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import rank, col
windowSpec=Window.partitionBy("category").orderBy(col("product_price").desc())
ranked_df=products.withColumn("rank", rank().over(windowSpec))
ranked_df.show()
# Out:
# +----------+------------+-----------+-------------+--------------+----+
# |product_id|product_name|   category|product_price|price_in_lakhs|rank|
# +----------+------------+-----------+-------------+--------------+----+
# |       101|      Laptop|Electronics|        75000|         75000|   1|
# |       107|  Smartphone|Electronics|        40000|         40000|   2|
# |       110|      Tablet|Electronics|        30000|         30000|   3|
# |       104|     Monitor|Electronics|        12000|         12000|   4|
# |       102|  Headphones|Electronics|         3000|          3000|   5|
# |       103|    Keyboard|Electronics|         1500|          1500|   6|
# |       106|        Desk|  Furniture|        15000|         15000|   1|
# |       105|Office Chair|  Furniture|         7000|          7000|   2|
# |       108|    Notebook| Stationery|          100|           100|   1|
# |       109|         Pen| Stationery|           20|            20|   2|
# ...

# %%
windowSpec=Window.orderBy("signup_date")
customers.withColumn("row_num",row_number().over(windowSpec)).show()
# Out:
# +-----------+-------------+---------+---+-----------+---------+-------+
# |customer_id|customer_name|     city|age|signup_date|age_group|row_num|
# +-----------+-------------+---------+---+-----------+---------+-------+
# |          1|         Amit|Hyderabad| 28| 2023-01-10|    Young|      1|
# |          2|        Priya|Bangalore| 32| 2023-02-12|    Adult|      2|
# |          3|        Rahul|   Mumbai| 29| 2023-03-14|    Young|      3|
# |          4|        Sneha|    Delhi| 35| 2023-04-15|    Adult|      4|
# |          5|        Arjun|  Chennai| 27| 2023-05-11|    Young|      5|
# |          6|        Meera|Hyderabad| 31| 2023-06-10|    Adult|      6|
# |          7|        Karan|     Pune| 33| 2023-06-22|    Adult|      7|
# |          8|         Neha|    Delhi| 30| 2023-07-10|    Adult|      8|
# |          9|        Divya|Bangalore| 26| 2023-07-15|    Young|      9|
# |         10|       Vikram|   Mumbai| 40| 2023-08-01|   Senior|     10|
# ...

# %%
customer_rev=full_df.groupBy("customer_name").agg(sum("revenue").alias("total_revenue"))
windowSpec=Window.orderBy(col("total_revenue").desc())
customer_rev.withColumn("rank",rank().over(windowSpec)).show()
# Out:
# +-------------+-------------+----+
# |customer_name|total_revenue|rank|
# +-------------+-------------+----+
# |         Amit|        81000|   1|
# |        Rahul|        75000|   2|
# |        Arjun|        40000|   3|
# |         Neha|        30000|   4|
# |        Sneha|        12000|   5|
# |        Meera|         9000|   6|
# |        Karan|         3000|   7|
# |        Priya|         1500|   8|
# |        Divya|          500|   9|
# |       Vikram|          200|  10|
# +-------------+-------------+----+

# %%
from pyspark.sql.functions import sum
customer_rev=full_df.groupBy("customer_name").agg(sum("revenue").alias("total_revenue"))
from pyspark.sql.window import Window
from pyspark.sql.functions import dense_rank, col
windowSpec=Window.orderBy(col("total_revenue").desc())

# %%
customer_rev.withColumn("dense_rank",dense_rank().over(windowSpec)).show()
# Out:
# +-------------+-------------+----------+
# |customer_name|total_revenue|dense_rank|
# +-------------+-------------+----------+
# |         Amit|        81000|         1|
# |        Rahul|        75000|         2|
# |        Arjun|        40000|         3|
# |         Neha|        30000|         4|
# |        Sneha|        12000|         5|
# |        Meera|         9000|         6|
# |        Karan|         3000|         7|
# |        Priya|         1500|         8|
# |        Divya|          500|         9|
# |       Vikram|          200|        10|
# +-------------+-------------+----------+

# %%
city_rev=full_df.groupBy("city","customer_name").agg(sum("revenue").alias("total_revenue"))
windowSpec=Window.partitionBy("city").orderBy(col("total_revenue").desc())
top_city_customer=city_rev.withColumn("rank",rank().over(windowSpec)).filter(col("rank")==1)
top_city_customer.show()
# Out:
# +---------+-------------+-------------+----+
# |     city|customer_name|total_revenue|rank|
# +---------+-------------+-------------+----+
# |Bangalore|        Priya|         1500|   1|
# |  Chennai|        Arjun|        40000|   1|
# |    Delhi|         Neha|        30000|   1|
# |Hyderabad|         Amit|        81000|   1|
# |   Mumbai|        Rahul|        75000|   1|
# |     Pune|        Karan|         3000|   1|
# +---------+-------------+-------------+----+

# %%
product_rev=full_df.groupBy("category","product_name").agg(sum("revenue").alias("total_revenue"))
windowSpec=Window.partitionBy("category").orderBy(col("total_revenue").desc())
top_products=product_rev.withColumn("rank",rank().over(windowSpec)).filter(col("rank")==1)
top_products.show()
# Out:
# +-----------+------------+-------------+----+
# |   category|product_name|total_revenue|rank|
# +-----------+------------+-------------+----+
# |Electronics|      Laptop|       150000|   1|
# | Stationery|    Notebook|          500|   1|
# +-----------+------------+-------------+----+

# %%
from pyspark.sql.functions import sum
date_rev=full_df.groupBy("order_date").agg(sum("revenue").alias("daily_revenue"))
windowSpec=Window.orderBy("order_date")
date_rev.withColumn("running_total",sum("daily_revenue").over(windowSpec)).show()
# Out:
# +----------+-------------+-------------+
# |order_date|daily_revenue|running_total|
# +----------+-------------+-------------+
# |2024-03-01|        81000|        81000|
# |2024-03-02|         1500|        82500|
# |2024-03-03|        75000|       157500|
# |2024-03-04|        12000|       169500|
# |2024-03-05|        40000|       209500|
# |2024-03-06|         9000|       218500|
# |2024-03-07|         3000|       221500|
# |2024-03-08|        30000|       251500|
# |2024-03-09|          500|       252000|
# |2024-03-10|          200|       252200|
# +----------+-------------+-------------+

# %%
product_rev=full_df.groupBy("product_name").agg(sum("revenue").alias("total_revenue"))
windowSpec=Window.orderBy("product_name")
product_rev.withColumn("running_total",sum("total_revenue").over(windowSpec)).show()
# Out:
# +------------+-------------+-------------+
# |product_name|total_revenue|running_total|
# +------------+-------------+-------------+
# |  Headphones|        15000|        15000|
# |    Keyboard|         4500|        19500|
# |      Laptop|       150000|       169500|
# |     Monitor|        12000|       181500|
# |    Notebook|          500|       182000|
# |         Pen|          200|       182200|
# |  Smartphone|        40000|       222200|
# |      Tablet|        30000|       252200|
# +------------+-------------+-------------+

# %%
windowSpec=Window.orderBy(col("amount").desc())
payments.withColumn("rank",rank().over(windowSpec)).show()
# Out:
# +----------+--------+------------+------+----+
# |payment_id|order_id|payment_type|amount|rank|
# +----------+--------+------------+------+----+
# |         1|       1| Credit Card| 81000|   1|
# |         3|       3|  Debit Card| 75000|   2|
# |         5|       5|         UPI| 40000|   3|
# |         8|       8| Credit Card| 30000|   4|
# |         4|       4| Credit Card| 12000|   5|
# |         6|       6|         UPI|  9000|   6|
# |         7|       7|  Debit Card|  3000|   7|
# |         2|       2|         UPI|  1500|   8|
# |         9|       9|         UPI|   500|   9|
# |        10|      10|         UPI|   200|  10|
# +----------+--------+------------+------+----+

# %%
sc=spark.sparkContext
logs=sc.textFile("logs.txt")

# %%
logs.count()
# Out:
# 20

# %%
logs.map(lambda x:x.split(" ")[1]).collect()
# Out:
# ['Amit',
#  'Priya',
#  'Rahul',
#  'Amit',
#  'Sneha',
#  'Amit',
#  'Priya',
#  'Arjun',
#  'Sneha',
#  'Rahul',
#  'Amit',
#  'Neha',
#  'Neha',
#  'Vikram',
#  'Vikram',
#  'Farhan',
#  'Farhan',
#  'Farhan',
#  'Simran',
#  'Simran']

# %%
logs.map(lambda x:x.split(" ")[0]).collect()
# Out:
# ['login',
#  'login',
#  'view',
#  'purchase',
#  'view',
#  'login',
#  'purchase',
#  'view',
#  'purchase',
#  'login',
#  'logout',
#  'login',
#  'purchase',
#  'view',
#  'purchase',
#  'login',
#  'view',
#  'purchase',
#  'login',
#  'purchase']

# %%
logs.map(lambda x:x.split(" ")[1]).distinct().collect()
# Out:
# ['Amit',
#  'Vikram',
#  'Simran',
#  'Priya',
#  'Rahul',
#  'Sneha',
#  'Arjun',
#  'Neha',
#  'Farhan']

# %%
logs.filter(lambda x:x.startswith("login")).count()
# Out:
# 7

# %%
logs.filter(lambda x:x.startswith("purchase")).count()
# Out:
# 7

# %%
logs.filter(lambda x:x.startswith("view")).count()
# Out:
# 5

# %%
logs.map(lambda x:(x.split(" ")[1],1)).collect()
# Out:
# [('Amit', 1),
#  ('Priya', 1),
#  ('Rahul', 1),
#  ('Amit', 1),
#  ('Sneha', 1),
#  ('Amit', 1),
#  ('Priya', 1),
#  ('Arjun', 1),
#  ('Sneha', 1),
#  ('Rahul', 1),
#  ('Amit', 1),
#  ('Neha', 1),
#  ('Neha', 1),
#  ('Vikram', 1),
#  ('Vikram', 1),
#  ('Farhan', 1),
#  ('Farhan', 1),
#  ('Farhan', 1),
#  ('Simran', 1),
#  ('Simran', 1)]

# %%
logs.map(lambda x:(x.split(" ")[1],1)).reduceByKey(lambda a,b:a+b).collect()
# Out:
# [('Amit', 4),
#  ('Vikram', 2),
#  ('Simran', 2),
#  ('Priya', 2),
#  ('Rahul', 2),
#  ('Sneha', 2),
#  ('Arjun', 1),
#  ('Neha', 2),
#  ('Farhan', 3)]

# %%
logs.map(lambda x:(x.split(" ")[1],1)).reduceByKey(lambda a,b:a+b).sortBy(lambda x:x[1],ascending=False).take(10)
# Out:
# [('Amit', 4),
#  ('Farhan', 3),
#  ('Vikram', 2),
#  ('Simran', 2),
#  ('Priya', 2),
#  ('Rahul', 2),
#  ('Sneha', 2),
#  ('Neha', 2),
#  ('Arjun', 1)]

# %%
customers.createOrReplaceTempView("customers")
orders.createOrReplaceTempView("orders")
products.createOrReplaceTempView("products")
payments.createOrReplaceTempView("payments")
order_items.createOrReplaceTempView("order_items")

# %%
spark.sql("SELECT * FROM customers").show()
# Out:
# +-----------+-------------+---------+---+-----------+---------+
# |customer_id|customer_name|     city|age|signup_date|age_group|
# +-----------+-------------+---------+---+-----------+---------+
# |          1|         Amit|Hyderabad| 28| 2023-01-10|    Young|
# |          2|        Priya|Bangalore| 32| 2023-02-12|    Adult|
# |          3|        Rahul|   Mumbai| 29| 2023-03-14|    Young|
# |          4|        Sneha|    Delhi| 35| 2023-04-15|    Adult|
# |          5|        Arjun|  Chennai| 27| 2023-05-11|    Young|
# |          6|        Meera|Hyderabad| 31| 2023-06-10|    Adult|
# |          7|        Karan|     Pune| 33| 2023-06-22|    Adult|
# |          8|         Neha|    Delhi| 30| 2023-07-10|    Adult|
# |          9|        Divya|Bangalore| 26| 2023-07-15|    Young|
# |         10|       Vikram|   Mumbai| 40| 2023-08-01|   Senior|
# |         11|         Ritu|Hyderabad| 34| 2023-08-10|    Adult|
# |         12|       Sanjay|    Delhi| 38| 2023-08-21|    Adult|
# ...

# %%
spark.sql("SELECT * FROM customers WHERE AGE>30").show()
# Out:
# +-----------+-------------+---------+---+-----------+---------+
# |customer_id|customer_name|     city|age|signup_date|age_group|
# +-----------+-------------+---------+---+-----------+---------+
# |          2|        Priya|Bangalore| 32| 2023-02-12|    Adult|
# |          4|        Sneha|    Delhi| 35| 2023-04-15|    Adult|
# |          6|        Meera|Hyderabad| 31| 2023-06-10|    Adult|
# |          7|        Karan|     Pune| 33| 2023-06-22|    Adult|
# |         10|       Vikram|   Mumbai| 40| 2023-08-01|   Senior|
# |         11|         Ritu|Hyderabad| 34| 2023-08-10|    Adult|
# |         12|       Sanjay|    Delhi| 38| 2023-08-21|    Adult|
# |         14|       Farhan|   Mumbai| 36| 2023-09-10|    Adult|
# +-----------+-------------+---------+---+-----------+---------+

# %%
spark.sql(""" SELECT city,COUNT(*) as total_customers FROM customers GROUP BY city""").show()
# Out:
# +---------+---------------+
# |     city|total_customers|
# +---------+---------------+
# |Bangalore|              3|
# |  Chennai|              2|
# |   Mumbai|              3|
# |     Pune|              1|
# |    Delhi|              3|
# |Hyderabad|              3|
# +---------+---------------+

# %%
spark.sql(""" SELECT city,AVG(age) as avg_age FROM customers GROUP BY city""").show()
# Out:
# +---------+------------------+
# |     city|           avg_age|
# +---------+------------------+
# |Bangalore|27.666666666666668|
# |  Chennai|              27.5|
# |   Mumbai|              35.0|
# |     Pune|              33.0|
# |    Delhi|34.333333333333336|
# |Hyderabad|              31.0|
# +---------+------------------+

# %%
spark.sql(""" SELECT c.customer_name,o.order_id,o.status FROM customers c JOIN orders o ON c.customer_id=o.customer_id""").show()
# Out:
# +-------------+--------+---------+
# |customer_name|order_id|   status|
# +-------------+--------+---------+
# |         Amit|       1|Delivered|
# |        Priya|       2|Delivered|
# |        Rahul|       3|Cancelled|
# |        Sneha|       4|Delivered|
# |        Arjun|       5|Delivered|
# |        Meera|       6|Delivered|
# |        Karan|       7|  Pending|
# |         Neha|       8|Delivered|
# |        Divya|       9|Delivered|
# |       Vikram|      10|Delivered|
# +-------------+--------+---------+

# %%
spark.sql("""SELECT customer_id,COUNT(*) as total_orders FROM orders GROUP BY customer_id""").show()
# Out:
# +-----------+------------+
# |customer_id|total_orders|
# +-----------+------------+
# |          1|           1|
# |          6|           1|
# |          3|           1|
# |          5|           1|
# |          9|           1|
# |          4|           1|
# |          8|           1|
# |          7|           1|
# |         10|           1|
# |          2|           1|
# +-----------+------------+

# %%
spark.sql("""SELECT oi.order_id,p.product_name,oi.quantity FROM order_items oi JOIN products p ON oi.product_id=p.product_id""").show()
# Out:
# +--------+------------+--------+
# |order_id|product_name|quantity|
# +--------+------------+--------+
# |       3|      Laptop|       1|
# |       1|      Laptop|       1|
# |       6|  Headphones|       3|
# |       1|  Headphones|       2|
# |       7|    Keyboard|       2|
# |       2|    Keyboard|       1|
# |       4|     Monitor|       1|
# |       5|  Smartphone|       1|
# |       9|    Notebook|       5|
# |      10|         Pen|      10|
# |       8|      Tablet|       1|
# +--------+------------+--------+

# %%
spark.sql("""SELECT oi.order_id,p.product_name,oi.quantity * p.product_price AS revenue FROM order_items oi JOIN products p ON oi.product_id=p.product_id""").show()
# Out:
# +--------+------------+-------+
# |order_id|product_name|revenue|
# +--------+------------+-------+
# |       3|      Laptop|  75000|
# |       1|      Laptop|  75000|
# |       6|  Headphones|   9000|
# |       1|  Headphones|   6000|
# |       7|    Keyboard|   3000|
# |       2|    Keyboard|   1500|
# |       4|     Monitor|  12000|
# |       5|  Smartphone|  40000|
# |       9|    Notebook|    500|
# |      10|         Pen|    200|
# |       8|      Tablet|  30000|
# +--------+------------+-------+

# %%
spark.sql("""SELECT c.customer_name,SUM(oi.quantity * p.product_price) AS total_revenue FROM customers c JOIN orders o ON c.customer_id=o.customer_id JOIN order_items oi ON o.order_id=oi.order_id JOIN products p ON oi.product_id=p.product_id GROUP BY c.customer_name ORDER BY total_revenue DESC LIMIT 3""").show()
# Out:
# +-------------+-------------+
# |customer_name|total_revenue|
# +-------------+-------------+
# |         Amit|        81000|
# |        Rahul|        75000|
# |        Arjun|        40000|
# +-------------+-------------+

# %%
spark.sql(""" SELECT p.product_name,SUM(oi.quantity*p.product_price) AS total_revenue FROM order_items oi JOIN products p ON oi.product_id=p.product_id GROUP BY p.product_name ORDER BY total_revenue DESC LIMIT 1 """).show()
# Out:
# +------------+-------------+
# |product_name|total_revenue|
# +------------+-------------+
# |      Laptop|       150000|
# +------------+-------------+

# %%
from pyspark.sql.functions import col
full_df=orders.join(customers,"customer_id").join(order_items,"order_id").join(products,"product_id").join(payments,"order_id")

# %%
full_df=full_df.withColumn("revenue",col("quantity")*col("product_price"))

# %%
from pyspark.sql.functions import sum
top_customers=full_df.groupBy("customer_name").agg(sum("revenue").alias("total_revenue")).orderBy(col("total_revenue").desc())
top_customers.show()
# Out:
# +-------------+-------------+
# |customer_name|total_revenue|
# +-------------+-------------+
# |         Amit|        81000|
# |        Rahul|        75000|
# |        Arjun|        40000|
# |         Neha|        30000|
# |        Sneha|        12000|
# |        Meera|         9000|
# |        Karan|         3000|
# |        Priya|         1500|
# |        Divya|          500|
# |       Vikram|          200|
# +-------------+-------------+

# %%
top_products=full_df.groupBy("product_name").agg(sum("revenue").alias("total_revenue")).orderBy(col("total_revenue").desc())
top_products.show()
# Out:
# +------------+-------------+
# |product_name|total_revenue|
# +------------+-------------+
# |      Laptop|       150000|
# |  Smartphone|        40000|
# |      Tablet|        30000|
# |  Headphones|        15000|
# |     Monitor|        12000|
# |    Keyboard|         4500|
# |    Notebook|          500|
# |         Pen|          200|
# +------------+-------------+

# %%
city_revenue=full_df.groupBy("city").agg(sum("revenue").alias("total_revenue")).orderBy(col("total_revenue").desc())
city_revenue.show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Hyderabad|        90000|
# |   Mumbai|        75200|
# |    Delhi|        42000|
# |  Chennai|        40000|
# |     Pune|         3000|
# |Bangalore|         2000|
# +---------+-------------+

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import dense_rank
customer_rev=full_df.groupBy("customer_name").agg(sum("revenue").alias("total_revenue"))
windowSpec=Window.orderBy(col("total_revenue").desc())
ranked_customers=customer_rev.withColumn("rank",dense_rank().over(windowSpec))
ranked_customers.show()
# Out:
# +-------------+-------------+----+
# |customer_name|total_revenue|rank|
# +-------------+-------------+----+
# |         Amit|        81000|   1|
# |        Rahul|        75000|   2|
# |        Arjun|        40000|   3|
# |         Neha|        30000|   4|
# |        Sneha|        12000|   5|
# |        Meera|         9000|   6|
# |        Karan|         3000|   7|
# |        Priya|         1500|   8|
# |        Divya|          500|   9|
# |       Vikram|          200|  10|
# +-------------+-------------+----+

# %%
final_df=full_df.select("customer_name","city","product_name","category","quantity","product_price","revenue")

# %%
final_df.write.mode("overwrite").csv("ecommerce_report",header=True)
