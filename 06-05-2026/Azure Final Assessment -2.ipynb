# %%
products_data=[
(101,"Rice Bag","Groceries","Hyderabad",1200,50),
(102,"Wheat Flour","Groceries","Bengaluru",900,80),
(103,"Sunflower Oil","Groceries","Mumbai",1800,40),
(104,"Milk Pack","Dairy","Chennai",60,200),
(105,"Cheese Block","Dairy","Delhi",450,70),
(106,"Soap","Personal Care","Kolkata",120,300),
(107,"Shampoo","Personal Care","Pune",320,150),
(108,"Toothpaste","Personal Care","Ahmedabad",90,250),
(109,"Notebook","Stationery","Hyderabad",75,500),
(110,"Pen Pack","Stationery","Mumbai",110,400),
(111,"LED TV","Electronics","Delhi",45000,15),
(112,"Refrigerator","Electronics","Chennai",38000,10),
(113,"Washing Machine","Electronics","Bengaluru",29000,12),
(114,"Mobile Phone","Electronics","Hyderabad",25000,35),
(115,"Laptop","Electronics","Pune",62000,18),
(116,"Air Conditioner","Electronics","Mumbai",42000,9),
(117,"Mixer Grinder","Home Appliances","Kolkata",3500,45),
(118,"Water Purifier","Home Appliances","Delhi",12000,20),
(119,"Ceiling Fan","Home Appliances","Ahmedabad",2800,60),
(120,"Gas Stove","Home Appliances","Chennai",5500,25)
]
products_columns=["product_id","product_name","category","warehouse_city","price","stock_quantity"]
products_df=spark.createDataFrame(products_data,products_columns)
display(products_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
suppliers_data=[
(201,"Reddy Traders","Hyderabad","Groceries"),
(202,"Fresh Dairy Ltd","Chennai","Dairy"),
(203,"CarePlus Suppliers","Mumbai","Personal Care"),
(204,"Elite Electronics","Delhi","Electronics"),
(205,"OfficeKart","Bengaluru","Stationery"),
(206,"HomeNeeds Pvt Ltd","Pune","Home Appliances"),
(207,"National Grocers","Ahmedabad","Groceries"),
(208,"Smart Electronics","Kolkata","Electronics"),
(209,"Daily Essentials","Hyderabad","Personal Care"),
(210,"Kitchen World","Chennai","Home Appliances")
]
suppliers_columns=["supplier_id","supplier_name","supplier_city","specialization"]
suppliers_df=spark.createDataFrame(suppliers_data,suppliers_columns)
display(suppliers_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
orders_data=[
(301,101,201,"2024-04-01",20,"Delivered"),
(302,102,201,"2024-04-01",35,"Delivered"),
(303,111,204,"2024-04-02",2,"Delivered"),
(304,114,208,"2024-04-02",5,"Pending"),
(305,115,204,"2024-04-03",3,"Delivered"),
(306,104,202,"2024-04-03",50,"Delivered"),
(307,105,202,"2024-04-04",18,"Cancelled"),
(308,117,206,"2024-04-04",7,"Delivered"),
(309,118,210,"2024-04-05",4,"Pending"),
(310,119,206,"2024-04-05",12,"Delivered"),
(311,120,210,"2024-04-06",6,"Delivered"),
(312,113,204,"2024-04-06",4,"Delivered"),
(313,116,208,"2024-04-07",2,"Pending"),
(314,109,205,"2024-04-07",80,"Delivered"),
(315,110,205,"2024-04-08",120,"Delivered"),
(316,106,203,"2024-04-08",60,"Cancelled"),
(317,107,209,"2024-04-09",25,"Delivered"),
(318,108,203,"2024-04-09",40,"Delivered"),
(319,112,208,"2024-04-10",2,"Pending"),
(320,101,207,"2024-04-10",15,"Delivered")
]
orders_columns=["order_id","product_id","supplier_id","order_date","quantity","order_status"]
orders_df=spark.createDataFrame(orders_data,orders_columns)
display(orders_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
payments_data=[
(401,301,24000,"UPI","Paid"),
(402,302,31500,"Credit Card","Paid"),
(403,303,90000,"Bank Transfer","Paid"),
(404,304,125000,"UPI","Pending"),
(405,305,186000,"Bank Transfer","Paid"),
(406,306,3000,"Cash","Paid"),
(407,307,8100,"UPI","Cancelled"),
(408,308,24500,"Debit Card","Paid"),
(409,309,48000,"UPI","Pending"),
(410,310,33600,"Cash","Paid"),
(411,311,33000,"Credit Card","Paid"),
(412,312,116000,"Bank Transfer","Paid"),
(413,313,84000,"UPI","Pending"),
(414,314,6000,"Cash","Paid"),
(415,315,13200,"UPI","Paid"),
(416,316,7200,"Cash","Cancelled"),
(417,317,8000,"UPI","Paid"),
(418,318,3600,"Debit Card","Paid"),
(419,319,76000,"Bank Transfer","Pending"),
(420,320,18000,"UPI","Paid")
]
payments_columns=["payment_id","order_id","bill_amount","payment_mode","payment_status"]
payments_df=spark.createDataFrame(payments_data,payments_columns)
display(payments_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
daily_orders_data=[
(321,114,204,"2024-04-11",3,"Delivered"),
(322,118,210,"2024-04-11",2,"Delivered"),
(304,114,208,"2024-04-02",5,"Delivered"),
(319,112,208,"2024-04-10",2,"Delivered"),
(323,120,210,"2024-04-12",1,"Pending")
]
daily_orders_columns=["order_id","product_id","supplier_id","order_date","quantity","order_status"]
daily_orders_df=spark.createDataFrame(daily_orders_data,daily_orders_columns)
display(daily_orders_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>product_id</th><th>supplier_id</th><th>order_date</th><th>quantity</th><th>order_status</th></tr></thead><tbody><tr><td>321</td><td>114</td><td>204</td><td>2024-04-11</td><td>3</td><td>Delivered</td></tr><tr><td>322</td><td>118</td><td>210</td><td>2024-04-11</td><td>2</td><td>Delivered</td></tr><tr><td>304</td><td>114</td><td>208</td><td>2024-04-02</td><td>5</td><td>Delivered</td></tr><tr><td>319</td><td>112</td><td>208</td><td>2024-04-10</td><td>2</td><td>Delivered</td></tr><tr><td>323</td><td>120</td><td>210</td><td>2024-04-12</td><td>1</td><td>Pending</td></tr></tbody></table></div>

# %%
display(products_df)
display(suppliers_df)
display(orders_df)
display(payments_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
products_df.printSchema()
suppliers_df.printSchema()
orders_df.printSchema()
payments_df.printSchema()
# Out:
# root
#  |-- product_id: long (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- warehouse_city: string (nullable = true)
#  |-- price: long (nullable = true)
#  |-- stock_quantity: long (nullable = true)
#
# root
#  |-- supplier_id: long (nullable = true)
#  |-- supplier_name: string (nullable = true)
#  |-- supplier_city: string (nullable = true)
#  |-- specialization: string (nullable = true)
#
# root
#  |-- order_id: long (nullable = true)
#  |-- product_id: long (nullable = true)
#  |-- supplier_id: long (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- quantity: long (nullable = true)
#  |-- order_status: string (nullable = true)
#
# root
#  |-- payment_id: long (nullable = true)
#  |-- order_id: long (nullable = true)
#  |-- bill_amount: long (nullable = true)
#  |-- payment_mode: string (nullable = true)
#  |-- payment_status: string (nullable = true)

# %%
print(products_df.count())
print(suppliers_df.count())
print(orders_df.count())
print(payments_df.count())
# Out:
# 20
# 10
# 20
# 20

# %%
print(products_df.count())
print(suppliers_df.count())
print(orders_df.count())
print(payments_df.count())
# Out:
# 20
# 10
# 20
# 20

# %%
products_df.show(10)
# Out:
# +----------+-------------+-------------+--------------+-----+--------------+
# |product_id| product_name|     category|warehouse_city|price|stock_quantity|
# +----------+-------------+-------------+--------------+-----+--------------+
# |       101|     Rice Bag|    Groceries|     Hyderabad| 1200|            50|
# |       102|  Wheat Flour|    Groceries|     Bengaluru|  900|            80|
# |       103|Sunflower Oil|    Groceries|        Mumbai| 1800|            40|
# |       104|    Milk Pack|        Dairy|       Chennai|   60|           200|
# |       105| Cheese Block|        Dairy|         Delhi|  450|            70|
# |       106|         Soap|Personal Care|       Kolkata|  120|           300|
# |       107|      Shampoo|Personal Care|          Pune|  320|           150|
# |       108|   Toothpaste|Personal Care|     Ahmedabad|   90|           250|
# |       109|     Notebook|   Stationery|     Hyderabad|   75|           500|
# ...

# %%
products_df.show(10)
# Out:
# +----------+-------------+-------------+--------------+-----+--------------+
# |product_id| product_name|     category|warehouse_city|price|stock_quantity|
# +----------+-------------+-------------+--------------+-----+--------------+
# |       101|     Rice Bag|    Groceries|     Hyderabad| 1200|            50|
# |       102|  Wheat Flour|    Groceries|     Bengaluru|  900|            80|
# |       103|Sunflower Oil|    Groceries|        Mumbai| 1800|            40|
# |       104|    Milk Pack|        Dairy|       Chennai|   60|           200|
# |       105| Cheese Block|        Dairy|         Delhi|  450|            70|
# |       106|         Soap|Personal Care|       Kolkata|  120|           300|
# |       107|      Shampoo|Personal Care|          Pune|  320|           150|
# |       108|   Toothpaste|Personal Care|     Ahmedabad|   90|           250|
# |       109|     Notebook|   Stationery|     Hyderabad|   75|           500|
# ...

# %%
products_df.select("product_name","category","stock_quantity").show()
# Out:
# +---------------+---------------+--------------+
# |   product_name|       category|stock_quantity|
# +---------------+---------------+--------------+
# |       Rice Bag|      Groceries|            50|
# |    Wheat Flour|      Groceries|            80|
# |  Sunflower Oil|      Groceries|            40|
# |      Milk Pack|          Dairy|           200|
# |   Cheese Block|          Dairy|            70|
# |           Soap|  Personal Care|           300|
# |        Shampoo|  Personal Care|           150|
# |     Toothpaste|  Personal Care|           250|
# |       Notebook|     Stationery|           500|
# |       Pen Pack|     Stationery|           400|
# |         LED TV|    Electronics|            15|
# |   Refrigerator|    Electronics|            10|
# |Washing Machine|    Electronics|            12|
# |   Mobile Phone|    Electronics|            35|
# |         Laptop|    Electronics|            18|
# |Air Conditioner|    Electronics|             9|
# ...

# %%
from pyspark.sql.functions import col
suppliers_df.filter((col("supplier_city")=="Hyderabad")|(col("supplier_city")=="Chennai")).show()
# Out:
# +-----------+----------------+-------------+---------------+
# |supplier_id|   supplier_name|supplier_city| specialization|
# +-----------+----------------+-------------+---------------+
# |        201|   Reddy Traders|    Hyderabad|      Groceries|
# |        202| Fresh Dairy Ltd|      Chennai|          Dairy|
# |        209|Daily Essentials|    Hyderabad|  Personal Care|
# |        210|   Kitchen World|      Chennai|Home Appliances|
# +-----------+----------------+-------------+---------------+

# %%
orders_df.filter(col("order_status")=="Delivered").show()
# Out:
# +--------+----------+-----------+----------+--------+------------+
# |order_id|product_id|supplier_id|order_date|quantity|order_status|
# +--------+----------+-----------+----------+--------+------------+
# |     301|       101|        201|2024-04-01|      20|   Delivered|
# |     302|       102|        201|2024-04-01|      35|   Delivered|
# |     303|       111|        204|2024-04-02|       2|   Delivered|
# |     305|       115|        204|2024-04-03|       3|   Delivered|
# |     306|       104|        202|2024-04-03|      50|   Delivered|
# |     308|       117|        206|2024-04-04|       7|   Delivered|
# |     310|       119|        206|2024-04-05|      12|   Delivered|
# |     311|       120|        210|2024-04-06|       6|   Delivered|
# |     312|       113|        204|2024-04-06|       4|   Delivered|
# |     314|       109|        205|2024-04-07|      80|   Delivered|
# |     315|       110|        205|2024-04-08|     120|   Delivered|
# ...

# %%
orders_df.filter(col("order_status")=="Pending").show()
# Out:
# +--------+----------+-----------+----------+--------+------------+
# |order_id|product_id|supplier_id|order_date|quantity|order_status|
# +--------+----------+-----------+----------+--------+------------+
# |     304|       114|        208|2024-04-02|       5|     Pending|
# |     309|       118|        210|2024-04-05|       4|     Pending|
# |     313|       116|        208|2024-04-07|       2|     Pending|
# |     319|       112|        208|2024-04-10|       2|     Pending|
# +--------+----------+-----------+----------+--------+------------+

# %%
products_df.filter(col("category")=="Electronics").show()
# Out:
# +----------+---------------+-----------+--------------+-----+--------------+
# |product_id|   product_name|   category|warehouse_city|price|stock_quantity|
# +----------+---------------+-----------+--------------+-----+--------------+
# |       111|         LED TV|Electronics|         Delhi|45000|            15|
# |       112|   Refrigerator|Electronics|       Chennai|38000|            10|
# |       113|Washing Machine|Electronics|     Bengaluru|29000|            12|
# |       114|   Mobile Phone|Electronics|     Hyderabad|25000|            35|
# |       115|         Laptop|Electronics|          Pune|62000|            18|
# |       116|Air Conditioner|Electronics|        Mumbai|42000|             9|
# +----------+---------------+-----------+--------------+-----+--------------+

# %%
products_df.filter(col("stock_quantity")<20).show()
# Out:
# +----------+---------------+-----------+--------------+-----+--------------+
# |product_id|   product_name|   category|warehouse_city|price|stock_quantity|
# +----------+---------------+-----------+--------------+-----+--------------+
# |       111|         LED TV|Electronics|         Delhi|45000|            15|
# |       112|   Refrigerator|Electronics|       Chennai|38000|            10|
# |       113|Washing Machine|Electronics|     Bengaluru|29000|            12|
# |       115|         Laptop|Electronics|          Pune|62000|            18|
# |       116|Air Conditioner|Electronics|        Mumbai|42000|             9|
# +----------+---------------+-----------+--------------+-----+--------------+

# %%
from pyspark.sql.functions import to_date
orders_df=orders_df.withColumn("order_date",to_date(col("order_date"),"yyyy-MM-dd"))
orders_df.printSchema()
# Out:
# root
#  |-- order_id: long (nullable = true)
#  |-- product_id: long (nullable = true)
#  |-- supplier_id: long (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- quantity: long (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
orders_df=orders_df.join(products_df.select("product_id","price"),"product_id")
orders_df=orders_df.withColumn("total_order_value",col("price")*col("quantity"))
display(orders_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import when,col
products_df=products_df.withColumn("stock_status",when(col("stock_quantity")<20,"Low").otherwise("Available"))
display(products_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import when, col
orders_df=orders_df.withColumn("order_priority",when(col("quantity")>50,"High").when(col("quantity")>=20,"Medium").otherwise("Low"))
display(orders_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
products_df=products_df.withColumn("expensive_product_flag",when(col("price")>30000,"Yes").otherwise("No"))
display(products_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import col, upper
products_df=products_df.withColumn("category", upper(col("category")))
display(products_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
products_df=products_df.withColumnRenamed("warehouse_city","inventory_city")
display(products_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
products_df=products_df.withColumn("inventory_value",col("price")*col("stock_quantity"))
display(products_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
orders_df=orders_df.drop("price")
display(orders_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
products_df=products_df.withColumn("low_stock_flag",when(col("stock_quantity")<20,"Yes").otherwise("No"))
display(products_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
product_orders_df=products_df.join(orders_df,"product_id","inner")
display(product_orders_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
order_supplier_df=orders_df.join(suppliers_df,"supplier_id","inner")
display(order_supplier_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
order_payment_df=orders_df.join(payments_df,"order_id","inner")
display(order_payment_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
final_df=products_df.join(orders_df,"product_id").join(suppliers_df,"supplier_id").join(payments_df,"order_id")
display(final_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
final_df.select("product_name","supplier_name","quantity","bill_amount").show()
# Out:
# +---------------+------------------+--------+-----------+
# |   product_name|     supplier_name|quantity|bill_amount|
# +---------------+------------------+--------+-----------+
# |       Rice Bag|     Reddy Traders|      20|      24000|
# |    Wheat Flour|     Reddy Traders|      35|      31500|
# |         LED TV| Elite Electronics|       2|      90000|
# |   Mobile Phone| Smart Electronics|       5|     125000|
# |         Laptop| Elite Electronics|       3|     186000|
# |      Milk Pack|   Fresh Dairy Ltd|      50|       3000|
# |   Cheese Block|   Fresh Dairy Ltd|      18|       8100|
# |  Mixer Grinder| HomeNeeds Pvt Ltd|       7|      24500|
# | Water Purifier|     Kitchen World|       4|      48000|
# |    Ceiling Fan| HomeNeeds Pvt Ltd|      12|      33600|
# |      Gas Stove|     Kitchen World|       6|      33000|
# |Washing Machine| Elite Electronics|       4|     116000|
# |Air Conditioner| Smart Electronics|       2|      84000|
# ...

# %%
final_df.filter(col("inventory_city")!=col("supplier_city")).select("supplier_name","inventory_city","supplier_city").show()
# Out:
# +------------------+--------------+-------------+
# |     supplier_name|inventory_city|supplier_city|
# +------------------+--------------+-------------+
# |     Reddy Traders|     Bengaluru|    Hyderabad|
# | Smart Electronics|     Hyderabad|      Kolkata|
# | Elite Electronics|          Pune|        Delhi|
# |   Fresh Dairy Ltd|         Delhi|      Chennai|
# | HomeNeeds Pvt Ltd|       Kolkata|         Pune|
# |     Kitchen World|         Delhi|      Chennai|
# | HomeNeeds Pvt Ltd|     Ahmedabad|         Pune|
# | Elite Electronics|     Bengaluru|        Delhi|
# | Smart Electronics|        Mumbai|      Kolkata|
# |        OfficeKart|     Hyderabad|    Bengaluru|
# |        OfficeKart|        Mumbai|    Bengaluru|
# |CarePlus Suppliers|       Kolkata|       Mumbai|
# |  Daily Essentials|          Pune|    Hyderabad|
# |CarePlus Suppliers|     Ahmedabad|       Mumbai|
# | Smart Electronics|       Chennai|      Kolkata|
# |  National Grocers|     Hyderabad|    Ahmedabad|
# ...

# %%
final_df.filter((col("order_status")=="Delivered")&(col("payment_status")=="Paid")).show()
# Out:
# +--------+-----------+----------+---------------+---------------+--------------+-----+--------------+------------+----------------------+---------------+--------------+----------+--------+------------+-----------------+--------------+------------------+-------------+---------------+----------+-----------+-------------+--------------+
# |order_id|supplier_id|product_id|   product_name|       category|inventory_city|price|stock_quantity|stock_status|expensive_product_flag|inventory_value|low_stock_flag|order_date|quantity|order_status|total_order_value|order_priority|     supplier_name|supplier_city| specialization|payment_id|bill_amount| payment_mode|payment_status|
# ...

# %%
final_df.filter((col("order_status")=="Pending")&(col("payment_status")=="Pending")).show()
# Out:
# +--------+-----------+----------+---------------+---------------+--------------+-----+--------------+------------+----------------------+---------------+--------------+----------+--------+------------+-----------------+--------------+-----------------+-------------+---------------+----------+-----------+-------------+--------------+
# |order_id|supplier_id|product_id|   product_name|       category|inventory_city|price|stock_quantity|stock_status|expensive_product_flag|inventory_value|low_stock_flag|order_date|quantity|order_status|total_order_value|order_priority|    supplier_name|supplier_city| specialization|payment_id|bill_amount| payment_mode|payment_status|
# ...

# %%
final_df.filter((col("order_status")=="Cancelled")&(col("payment_status")=="Cancelled")).show()
# Out:
# +--------+-----------+----------+------------+-------------+--------------+-----+--------------+------------+----------------------+---------------+--------------+----------+--------+------------+-----------------+--------------+------------------+-------------+--------------+----------+-----------+------------+--------------+
# |order_id|supplier_id|product_id|product_name|     category|inventory_city|price|stock_quantity|stock_status|expensive_product_flag|inventory_value|low_stock_flag|order_date|quantity|order_status|total_order_value|order_priority|     supplier_name|supplier_city|specialization|payment_id|bill_amount|payment_mode|payment_status|
# +--------+-----------+----------+------------+-------------+--------------+-----+--------------+------------+----------------------+---------------+--------------+----------+--------+------------+-----------------+--------------+------------------+-------------+--------------+----------+-----------+------------+--------------+
# ...

# %%
final_df.groupBy("product_id","product_name").count().filter(col("count")>1).show()
# Out:
# +----------+------------+-----+
# |product_id|product_name|count|
# +----------+------------+-----+
# |       101|    Rice Bag|    2|
# +----------+------------+-----+

# %%
products_df.groupBy("category").count().show()
# Out:
# +---------------+-----+
# |       category|count|
# +---------------+-----+
# |      GROCERIES|    3|
# |          DAIRY|    2|
# |  PERSONAL CARE|    3|
# |     STATIONERY|    2|
# |    ELECTRONICS|    6|
# |HOME APPLIANCES|    4|
# +---------------+-----+

# %%
orders_df.groupBy("order_status").count().show()
# Out:
# +------------+-----+
# |order_status|count|
# +------------+-----+
# |   Delivered|   14|
# |     Pending|    4|
# |   Cancelled|    2|
# +------------+-----+

# %%
suppliers_df.groupBy("supplier_city").count().show()
# Out:
# +-------------+-----+
# |supplier_city|count|
# +-------------+-----+
# |    Hyderabad|    2|
# |      Chennai|    2|
# |       Mumbai|    1|
# |        Delhi|    1|
# |    Bengaluru|    1|
# |         Pune|    1|
# |    Ahmedabad|    1|
# |      Kolkata|    1|
# +-------------+-----+

# %%
 from pyspark.sql.functions import sum 
 payments_df.agg(sum("bill_amount")).show()
# Out:
# +----------------+
# |sum(bill_amount)|
# +----------------+
# |          938700|
# +----------------+

# %%
from pyspark.sql.functions import avg 
payments_df.agg(avg("bill_amount")).show()
# Out:
# +----------------+
# |avg(bill_amount)|
# +----------------+
# |         46935.0|
# +----------------+

# %%
final_df.groupBy("category").agg(sum("bill_amount")).show()
# Out:
# +---------------+----------------+
# |       category|sum(bill_amount)|
# +---------------+----------------+
# |      GROCERIES|           73500|
# |    ELECTRONICS|          677000|
# |          DAIRY|           11100|
# |HOME APPLIANCES|          139100|
# |     STATIONERY|           19200|
# |  PERSONAL CARE|           18800|
# +---------------+----------------+

# %%
final_df.groupBy("supplier_name").agg(sum("bill_amount")).show()
# Out:
# +------------------+----------------+
# |     supplier_name|sum(bill_amount)|
# +------------------+----------------+
# |     Reddy Traders|           55500|
# | Smart Electronics|          285000|
# | Elite Electronics|          392000|
# |   Fresh Dairy Ltd|           11100|
# | HomeNeeds Pvt Ltd|           58100|
# |     Kitchen World|           81000|
# |        OfficeKart|           19200|
# |CarePlus Suppliers|           10800|
# |  Daily Essentials|            8000|
# |  National Grocers|           18000|
# +------------------+----------------+

# %%
final_df.groupBy("inventory_city").agg(sum("bill_amount")).show()
# Out:
# +--------------+----------------+
# |inventory_city|sum(bill_amount)|
# +--------------+----------------+
# |     Hyderabad|          173000|
# |     Bengaluru|          147500|
# |         Delhi|          146100|
# |          Pune|          194000|
# |       Chennai|          112000|
# |     Ahmedabad|           37200|
# |       Kolkata|           31700|
# |        Mumbai|           97200|
# +--------------+----------------+

# %%
final_df.groupBy("product_name").agg(sum("quantity").alias("total_sold")).orderBy(col("total_sold").desc()).show()
# Out:
# +---------------+----------+
# |   product_name|total_sold|
# +---------------+----------+
# |       Pen Pack|       120|
# |       Notebook|        80|
# |           Soap|        60|
# |      Milk Pack|        50|
# |     Toothpaste|        40|
# |       Rice Bag|        35|
# |    Wheat Flour|        35|
# |        Shampoo|        25|
# |   Cheese Block|        18|
# |    Ceiling Fan|        12|
# |  Mixer Grinder|         7|
# |      Gas Stove|         6|
# |   Mobile Phone|         5|
# | Water Purifier|         4|
# |Washing Machine|         4|
# |         Laptop|         3|
# |         LED TV|         2|
# |Air Conditioner|         2|
# |   Refrigerator|         2|
# +---------------+----------+

# %%
final_df.groupBy("product_name").agg(sum("quantity").alias("total_sold")).orderBy(col("total_sold")).show()
# Out:
# +---------------+----------+
# |   product_name|total_sold|
# +---------------+----------+
# |         LED TV|         2|
# |Air Conditioner|         2|
# |   Refrigerator|         2|
# |         Laptop|         3|
# | Water Purifier|         4|
# |Washing Machine|         4|
# |   Mobile Phone|         5|
# |      Gas Stove|         6|
# |  Mixer Grinder|         7|
# |    Ceiling Fan|        12|
# |   Cheese Block|        18|
# |        Shampoo|        25|
# |       Rice Bag|        35|
# |    Wheat Flour|        35|
# |     Toothpaste|        40|
# |      Milk Pack|        50|
# |           Soap|        60|
# |       Notebook|        80|
# |       Pen Pack|       120|
# +---------------+----------+

# %%
products_df.createOrReplaceTempView("products")
suppliers_df.createOrReplaceTempView("suppliers")
orders_df.createOrReplaceTempView("orders")
payments_df.createOrReplaceTempView("payments")
final_df.createOrReplaceTempView("final_table")

# %%
spark.sql("select * from products").show()
# Out:
# +----------+---------------+---------------+--------------+-----+--------------+------------+----------------------+---------------+--------------+
# |product_id|   product_name|       category|inventory_city|price|stock_quantity|stock_status|expensive_product_flag|inventory_value|low_stock_flag|
# +----------+---------------+---------------+--------------+-----+--------------+------------+----------------------+---------------+--------------+
# |       101|       Rice Bag|      GROCERIES|     Hyderabad| 1200|            50|   Available|                    No|          60000|            No|
# |       102|    Wheat Flour|      GROCERIES|     Bengaluru|  900|            80|   Available|                    No|          72000|            No|
# |       103|  Sunflower Oil|      GROCERIES|        Mumbai| 1800|            40|   Available|                    No|          72000|            No|
# ...

# %%
spark.sql("select * from final_table where category='ELECTRONICS'").show()
# Out:
# +--------+-----------+----------+---------------+-----------+--------------+-----+--------------+------------+----------------------+---------------+--------------+----------+--------+------------+-----------------+--------------+-----------------+-------------+--------------+----------+-----------+-------------+--------------+
# |order_id|supplier_id|product_id|   product_name|   category|inventory_city|price|stock_quantity|stock_status|expensive_product_flag|inventory_value|low_stock_flag|order_date|quantity|order_status|total_order_value|order_priority|    supplier_name|supplier_city|specialization|payment_id|bill_amount| payment_mode|payment_status|
# +--------+-----------+----------+---------------+-----------+--------------+-----+--------------+------------+----------------------+---------------+--------------+----------+--------+------------+-----------------+--------------+-----------------+-------------+--------------+----------+-----------+-------------+--------------+
# ...

# %%
spark.sql("select category,sum(bill_amount) as total_revenue from final_table group by category").show()
# Out:
# +---------------+-------------+
# |       category|total_revenue|
# +---------------+-------------+
# |      GROCERIES|        73500|
# |    ELECTRONICS|       677000|
# |          DAIRY|        11100|
# |HOME APPLIANCES|       139100|
# |     STATIONERY|        19200|
# |  PERSONAL CARE|        18800|
# +---------------+-------------+

# %%
spark.sql("select supplier_name,sum(bill_amount) as total_revenue from final_table group by supplier_name").show()
# Out:
# +------------------+-------------+
# |     supplier_name|total_revenue|
# +------------------+-------------+
# |     Reddy Traders|        55500|
# | Smart Electronics|       285000|
# | Elite Electronics|       392000|
# |   Fresh Dairy Ltd|        11100|
# | HomeNeeds Pvt Ltd|        58100|
# |     Kitchen World|        81000|
# |        OfficeKart|        19200|
# |CarePlus Suppliers|        10800|
# |  Daily Essentials|         8000|
# |  National Grocers|        18000|
# +------------------+-------------+

# %%
spark.sql("select * from final_table order by bill_amount desc limit 5").show()
# Out:
# +--------+-----------+----------+---------------+-----------+--------------+-----+--------------+------------+----------------------+---------------+--------------+----------+--------+------------+-----------------+--------------+-----------------+-------------+--------------+----------+-----------+-------------+--------------+
# |order_id|supplier_id|product_id|   product_name|   category|inventory_city|price|stock_quantity|stock_status|expensive_product_flag|inventory_value|low_stock_flag|order_date|quantity|order_status|total_order_value|order_priority|    supplier_name|supplier_city|specialization|payment_id|bill_amount| payment_mode|payment_status|
# +--------+-----------+----------+---------------+-----------+--------------+-----+--------------+------------+----------------------+---------------+--------------+----------+--------+------------+-----------------+--------------+-----------------+-------------+--------------+----------+-----------+-------------+--------------+
# ...

# %%
spark.sql("select supplier_name,count(order_id) as total_orders from final_table group by supplier_name").show()
# Out:
# +------------------+------------+
# |     supplier_name|total_orders|
# +------------------+------------+
# |     Reddy Traders|           2|
# | Smart Electronics|           3|
# | Elite Electronics|           3|
# |   Fresh Dairy Ltd|           2|
# | HomeNeeds Pvt Ltd|           2|
# |     Kitchen World|           2|
# |        OfficeKart|           2|
# |CarePlus Suppliers|           2|
# |  Daily Essentials|           1|
# |  National Grocers|           1|
# +------------------+------------+

# %%
spark.sql("select category,count(order_id) as total_orders from final_table group by category").show()
# Out:
# +---------------+------------+
# |       category|total_orders|
# +---------------+------------+
# |      GROCERIES|           3|
# |    ELECTRONICS|           6|
# |          DAIRY|           2|
# |HOME APPLIANCES|           4|
# |     STATIONERY|           2|
# |  PERSONAL CARE|           3|
# +---------------+------------+

# %%
spark.sql("select payment_mode,avg(bill_amount) as avg_payment from final_table group by payment_mode").show()
# Out:
# +-------------+-----------+
# | payment_mode|avg_payment|
# +-------------+-----------+
# |  Credit Card|    32250.0|
# |          UPI|    41037.5|
# |Bank Transfer|   117000.0|
# |         Cash|    12450.0|
# |   Debit Card|    14050.0|
# +-------------+-----------+

# %%
spark.sql("select product_name,sum(bill_amount) as total_revenue from final_table group by product_name having sum(bill_amount)>100000").show()
# Out:
# +---------------+-------------+
# |   product_name|total_revenue|
# +---------------+-------------+
# |         Laptop|       186000|
# |   Mobile Phone|       125000|
# |Washing Machine|       116000|
# +---------------+-------------+

# %%
from pyspark.sql.window import Window

# %%
from pyspark.sql.functions import rank
product_revenue_df=final_df.groupBy("category","product_name").agg(sum("bill_amount").alias("total_revenue"))
window_spec=Window.partitionBy("category").orderBy(col("total_revenue").desc())
product_revenue_df.withColumn("rank",rank().over(window_spec)).show()
# Out:
# +---------------+---------------+-------------+----+
# |       category|   product_name|total_revenue|rank|
# +---------------+---------------+-------------+----+
# |          DAIRY|   Cheese Block|         8100|   1|
# |          DAIRY|      Milk Pack|         3000|   2|
# |    ELECTRONICS|         Laptop|       186000|   1|
# |    ELECTRONICS|   Mobile Phone|       125000|   2|
# |    ELECTRONICS|Washing Machine|       116000|   3|
# |    ELECTRONICS|         LED TV|        90000|   4|
# |    ELECTRONICS|Air Conditioner|        84000|   5|
# |    ELECTRONICS|   Refrigerator|        76000|   6|
# |      GROCERIES|       Rice Bag|        42000|   1|
# |      GROCERIES|    Wheat Flour|        31500|   2|
# |HOME APPLIANCES| Water Purifier|        48000|   1|
# |HOME APPLIANCES|    Ceiling Fan|        33600|   2|
# |HOME APPLIANCES|      Gas Stove|        33000|   3|
# |HOME APPLIANCES|  Mixer Grinder|        24500|   4|
# |  PERSONAL CARE|        Shampoo|         8000|   1|
# ...

# %%
supplier_revenue_df=final_df.groupBy("supplier_city","supplier_name").agg(sum("bill_amount").alias("total_revenue"))
window_spec=Window.partitionBy("supplier_city").orderBy(col("total_revenue").desc())
supplier_revenue_df.withColumn("rank",rank().over(window_spec)).show()
# Out:
# +-------------+------------------+-------------+----+
# |supplier_city|     supplier_name|total_revenue|rank|
# +-------------+------------------+-------------+----+
# |    Ahmedabad|  National Grocers|        18000|   1|
# |    Bengaluru|        OfficeKart|        19200|   1|
# |      Chennai|     Kitchen World|        81000|   1|
# |      Chennai|   Fresh Dairy Ltd|        11100|   2|
# |        Delhi| Elite Electronics|       392000|   1|
# |    Hyderabad|     Reddy Traders|        55500|   1|
# |    Hyderabad|  Daily Essentials|         8000|   2|
# |      Kolkata| Smart Electronics|       285000|   1|
# |       Mumbai|CarePlus Suppliers|        10800|   1|
# |         Pune| HomeNeeds Pvt Ltd|        58100|   1|
# +-------------+------------------+-------------+----+

# %%
product_revenue_df=final_df.groupBy("category","product_name").agg(sum("bill_amount").alias("total_revenue"))
window_spec=Window.partitionBy("category").orderBy(col("total_revenue").desc())
from pyspark.sql.functions import sum, col, row_number
product_revenue_df.withColumn("row_num",row_number().over(window_spec)).filter(col("row_num")==1).show()
# Out:
# +---------------+--------------+-------------+-------+
# |       category|  product_name|total_revenue|row_num|
# +---------------+--------------+-------------+-------+
# |          DAIRY|  Cheese Block|         8100|      1|
# |    ELECTRONICS|        Laptop|       186000|      1|
# |      GROCERIES|      Rice Bag|        42000|      1|
# |HOME APPLIANCES|Water Purifier|        48000|      1|
# |  PERSONAL CARE|       Shampoo|         8000|      1|
# |     STATIONERY|      Pen Pack|        13200|      1|
# +---------------+--------------+-------------+-------+

# %%
from pyspark.sql.functions import dense_rank
supplier_bill_df=final_df.groupBy("supplier_name").agg(sum("bill_amount").alias("total_bill"))
window_spec=Window.orderBy(col("total_bill").desc())
supplier_bill_df.withColumn("dense_rank",dense_rank().over(window_spec)).show()
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# +------------------+----------+----------+
# |     supplier_name|total_bill|dense_rank|
# +------------------+----------+----------+
# | Elite Electronics|    392000|         1|
# | Smart Electronics|    285000|         2|
# |     Kitchen World|     81000|         3|
# | HomeNeeds Pvt Ltd|     58100|         4|
# |     Reddy Traders|     55500|         5|
# |        OfficeKart|     19200|         6|
# |  National Grocers|     18000|         7|
# |   Fresh Dairy Ltd|     11100|         8|
# |CarePlus Suppliers|     10800|         9|
# |  Daily Essentials|      8000|        10|
# +------------------+----------+----------+

# %%
supplier_revenue_df=final_df.groupBy("supplier_name").agg(sum("bill_amount").alias("total_revenue"))
window_spec=Window.orderBy(col("total_revenue").desc())
supplier_revenue_df.withColumn("rank",rank().over(window_spec)).filter(col("rank")<=2).show()
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# +-----------------+-------------+----+
# |    supplier_name|total_revenue|rank|
# +-----------------+-------------+----+
# |Elite Electronics|       392000|   1|
# |Smart Electronics|       285000|   2|
# +-----------------+-------------+----+

# %%
date_revenue_df=final_df.groupBy("order_date").agg(sum("bill_amount").alias("daily_revenue"))
window_spec=Window.orderBy("order_date")
date_revenue_df.withColumn("running_total",sum("daily_revenue").over(window_spec)).show()
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# +----------+-------------+-------------+
# |order_date|daily_revenue|running_total|
# +----------+-------------+-------------+
# |2024-04-01|        55500|        55500|
# |2024-04-02|       215000|       270500|
# |2024-04-03|       189000|       459500|
# |2024-04-04|        32600|       492100|
# |2024-04-05|        81600|       573700|
# |2024-04-06|       149000|       722700|
# |2024-04-07|        90000|       812700|
# |2024-04-08|        20400|       833100|
# |2024-04-09|        11600|       844700|
# |2024-04-10|        94000|       938700|
# +----------+-------------+-------------+

# %%
supplier_date_df=final_df.groupBy("supplier_name","order_date").agg(sum("bill_amount").alias("daily_revenue"))
window_spec=Window.partitionBy("supplier_name").orderBy("order_date")
supplier_date_df.withColumn("running_total",sum("daily_revenue").over(window_spec)).show()
# Out:
# +------------------+----------+-------------+-------------+
# |     supplier_name|order_date|daily_revenue|running_total|
# +------------------+----------+-------------+-------------+
# |CarePlus Suppliers|2024-04-08|         7200|         7200|
# |CarePlus Suppliers|2024-04-09|         3600|        10800|
# |  Daily Essentials|2024-04-09|         8000|         8000|
# | Elite Electronics|2024-04-02|        90000|        90000|
# | Elite Electronics|2024-04-03|       186000|       276000|
# | Elite Electronics|2024-04-06|       116000|       392000|
# |   Fresh Dairy Ltd|2024-04-03|         3000|         3000|
# |   Fresh Dairy Ltd|2024-04-04|         8100|        11100|
# | HomeNeeds Pvt Ltd|2024-04-04|        24500|        24500|
# | HomeNeeds Pvt Ltd|2024-04-05|        33600|        58100|
# |     Kitchen World|2024-04-05|        48000|        48000|
# |     Kitchen World|2024-04-06|        33000|        81000|
# |  National Grocers|2024-04-10|        18000|        18000|
# ...

# %%
city_revenue_df=final_df.groupBy("inventory_city").agg(sum("bill_amount").alias("total_revenue"))
window_spec=Window.orderBy(col("total_revenue").desc())
city_revenue_df.withColumn("rank",rank().over(window_spec)).show()
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# +--------------+-------------+----+
# |inventory_city|total_revenue|rank|
# +--------------+-------------+----+
# |          Pune|       194000|   1|
# |     Hyderabad|       173000|   2|
# |     Bengaluru|       147500|   3|
# |         Delhi|       146100|   4|
# |       Chennai|       112000|   5|
# |        Mumbai|        97200|   6|
# |     Ahmedabad|        37200|   7|
# |       Kolkata|        31700|   8|
# +--------------+-------------+----+

# %%
category_revenue_df=final_df.groupBy("category").agg(sum("bill_amount").alias("total_revenue"))
window_spec=Window.orderBy(col("total_revenue").desc())
category_revenue_df.withColumn("rank",rank().over(window_spec)).show()
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# +---------------+-------------+----+
# |       category|total_revenue|rank|
# +---------------+-------------+----+
# |    ELECTRONICS|       677000|   1|
# |HOME APPLIANCES|       139100|   2|
# |      GROCERIES|        73500|   3|
# |     STATIONERY|        19200|   4|
# |  PERSONAL CARE|        18800|   5|
# |          DAIRY|        11100|   6|
# +---------------+-------------+----+

# %%
category_revenue_df=final_df.groupBy("category").agg(sum("bill_amount").alias("total_revenue"))
window_spec=Window.orderBy(col("total_revenue").desc())
category_revenue_df.withColumn("rank",rank().over(window_spec)).show()
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# +---------------+-------------+----+
# |       category|total_revenue|rank|
# +---------------+-------------+----+
# |    ELECTRONICS|       677000|   1|
# |HOME APPLIANCES|       139100|   2|
# |      GROCERIES|        73500|   3|
# |     STATIONERY|        19200|   4|
# |  PERSONAL CARE|        18800|   5|
# |          DAIRY|        11100|   6|
# +---------------+-------------+----+

# %%
final_df.write.format("delta").mode("overwrite").saveAsTable("retail_final_delta")

# %%
new_orders_data=[(321,114,204,"2024-04-11",3,"Delivered"),(322,118,210,"2024-04-11",2,"Delivered")]
new_orders_columns=["order_id","product_id","supplier_id","order_date","quantity","order_status"]
new_orders_df=spark.createDataFrame(new_orders_data,new_orders_columns)
new_orders_df=new_orders_df.withColumn("order_date",to_date(col("order_date"),"yyyy-MM-dd"))
new_orders_df.write.format("delta").mode("append").option("mergeSchema","true").saveAsTable("retail_final_delta")

# %%
spark.sql("update retail_final_delta set order_status='Delivered' where order_id=304")
# Out:
# DataFrame[num_affected_rows: bigint]

# %%
spark.sql("update retail_final_delta set payment_status='Paid' where payment_status='Pending'")
# Out:
# DataFrame[num_affected_rows: bigint]

# %%
spark.sql("delete from retail_final_delta where order_status='Cancelled'")
# Out:
# DataFrame[num_affected_rows: bigint]

# %%
clean_orders_df=final_df.filter(col("order_status")=="Delivered")
clean_orders_df.write.format("delta").mode("overwrite").saveAsTable("clean_orders_delta")

# %%
spark.sql("describe history retail_final_delta").show()
# Out:
# +-------+-------------------+---------------+--------------------+--------------------+--------------------+----+----------------+-----------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# |version|          timestamp|         userId|            userName|           operation| operationParameters| job|        notebook|queryHistoryStatementId|           clusterId|readVersion|   isolationLevel|isBlindAppend|    operationMetrics|userMetadata|          engineInfo|
# +-------+-------------------+---------------+--------------------+--------------------+--------------------+----+----------------+-----------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# ...

# %%
spark.read.format("delta").option("versionAsOf",0).table("retail_final_delta").show()
# Out:
# +--------+-----------+----------+---------------+---------------+--------------+-----+--------------+------------+----------------------+---------------+--------------+----------+--------+------------+-----------------+--------------+------------------+-------------+---------------+----------+-----------+-------------+--------------+
# |order_id|supplier_id|product_id|   product_name|       category|inventory_city|price|stock_quantity|stock_status|expensive_product_flag|inventory_value|low_stock_flag|order_date|quantity|order_status|total_order_value|order_priority|     supplier_name|supplier_city| specialization|payment_id|bill_amount| payment_mode|payment_status|
# ...

# %%
latest_df=spark.read.format("delta").table("retail_final_delta")
old_df=spark.read.format("delta").option("versionAsOf",0).table("retail_final_delta")
display(latest_df)
display(old_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
spark.sql("vacuum retail_final_delta retain 168 hours dry run")
# Out:
# DataFrame[path: string]

# %%
daily_orders_data = [
(321,114,204,"2024-04-11",3,"Delivered"),
(322,118,210,"2024-04-11",2,"Delivered"),
(304,114,208,"2024-04-02",5,"Delivered"),
(319,112,208,"2024-04-10",2,"Delivered"),
(323,120,210,"2024-04-12",1,"Pending")
]
daily_orders_columns = [
"order_id",
"product_id",
"supplier_id",
"order_date",
"quantity",
"order_status"
]
daily_orders_df = spark.createDataFrame(daily_orders_data, daily_orders_columns)

# %%
orders_df.write.format("delta").mode("overwrite").saveAsTable("target_orders_delta")

# %%
spark.read.table("target_orders_delta").show()
# Out:
# +----------+--------+-----------+----------+--------+------------+-----------------+--------------+
# |product_id|order_id|supplier_id|order_date|quantity|order_status|total_order_value|order_priority|
# +----------+--------+-----------+----------+--------+------------+-----------------+--------------+
# |       116|     313|        208|2024-04-07|       2|     Pending|            84000|           Low|
# |       109|     314|        205|2024-04-07|      80|   Delivered|             6000|          High|
# |       110|     315|        205|2024-04-08|     120|   Delivered|            13200|          High|
# |       111|     303|        204|2024-04-02|       2|   Delivered|            90000|           Low|
# |       114|     304|        208|2024-04-02|       5|     Pending|           125000|           Low|
# |       115|     305|        204|2024-04-03|       3|   Delivered|           186000|           Low|
# ...

# %%
daily_orders_df.createOrReplaceTempView("daily_order_updates")

# %%
from delta.tables import DeltaTable
target_table=DeltaTable.forName(spark,"target_orders_delta")
source_df=daily_orders_df.withColumn("order_date",to_date(col("order_date"),"yyyy-MM-dd")).join(products_df.select("product_id","price"),"product_id").withColumn("total_order_value",col("price")*col("quantity")).withColumn("order_priority",when(col("quantity")>50,"High").when(col("quantity")>=20,"Medium").otherwise("Low")).drop("price")
target_table.alias("t").merge(source_df.alias("s"),"t.order_id=s.order_id").whenMatchedUpdateAll().whenNotMatchedInsertAll().execute()
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]

# %%
spark.sql("select * from target_orders_delta where order_id in (304,319)").show()
# Out:
# +----------+--------+-----------+----------+--------+------------+-----------------+--------------+
# |product_id|order_id|supplier_id|order_date|quantity|order_status|total_order_value|order_priority|
# +----------+--------+-----------+----------+--------+------------+-----------------+--------------+
# |       112|     319|        208|2024-04-10|       2|   Delivered|            76000|           Low|
# |       114|     304|        208|2024-04-02|       5|   Delivered|           125000|           Low|
# +----------+--------+-----------+----------+--------+------------+-----------------+--------------+

# %%
spark.sql("select * from target_orders_delta where order_id in (321,322,323)").show()
# Out:
# +----------+--------+-----------+----------+--------+------------+-----------------+--------------+
# |product_id|order_id|supplier_id|order_date|quantity|order_status|total_order_value|order_priority|
# +----------+--------+-----------+----------+--------+------------+-----------------+--------------+
# |       114|     321|        204|2024-04-11|       3|   Delivered|            75000|           Low|
# |       118|     322|        210|2024-04-11|       2|   Delivered|            24000|           Low|
# |       120|     323|        210|2024-04-12|       1|     Pending|             5500|           Low|
# +----------+--------+-----------+----------+--------+------------+-----------------+--------------+

# %%
spark.sql("select order_id,order_status from target_orders_delta where order_id in (304,319)").show()
# Out:
# +--------+------------+
# |order_id|order_status|
# +--------+------------+
# |     319|   Delivered|
# |     304|   Delivered|
# +--------+------------+

# %%
spark.sql("select * from target_orders_delta where order_id>=321").show()
# Out:
# +----------+--------+-----------+----------+--------+------------+-----------------+--------------+
# |product_id|order_id|supplier_id|order_date|quantity|order_status|total_order_value|order_priority|
# +----------+--------+-----------+----------+--------+------------+-----------------+--------------+
# |       114|     321|        204|2024-04-11|       3|   Delivered|            75000|           Low|
# |       118|     322|        210|2024-04-11|       2|   Delivered|            24000|           Low|
# |       120|     323|        210|2024-04-12|       1|     Pending|             5500|           Low|
# +----------+--------+-----------+----------+--------+------------+-----------------+--------------+

# %%
spark.sql("describe history target_orders_delta").show()
# Out:
# +-------+-------------------+---------------+--------------------+--------------------+--------------------+----+----------------+-----------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# |version|          timestamp|         userId|            userName|           operation| operationParameters| job|        notebook|queryHistoryStatementId|           clusterId|readVersion|   isolationLevel|isBlindAppend|    operationMetrics|userMetadata|          engineInfo|
# +-------+-------------------+---------------+--------------------+--------------------+--------------------+----+----------------+-----------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# ...

# %% [markdown]
#  MERGE is important because it updates existing records and inserts new records in one operation for efficient incremental loading.

# %%
spark.sql("show tables").show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | default|     bronze_hospital|      false|
# | default|  bronze_hospital_v2|      false|
# | default|      bronze_orderss|      false|
# | default|bronze_patient_vi...|      false|
# | default|bronze_patient_vi...|      false|
# | default| bronze_sales_inline|      false|
# | default|  clean_orders_delta|      false|
# | default|completed_visits_...|      false|
# | default|           customers|      false|
# | default| customers_delta_sql|      false|
# | default|    ecommerce_orders|      false|
# | default|gold_category_rev...|      false|
# | default|   gold_city_revenue|      false|
# | default|  gold_city_revenues|      false|
# | default|gold_city_sales_s...|      false|
# | default|gold_department_s...|      false|
# | default|gold_hospital_sum...|      false|
# | default|    gold_hospital_v2|      false|
# ...

# %%
spark.sql("create catalog retail_catalogsss")
# Out:
# DataFrame[]

# %%
spark.sql("create schema retail_catalogsss.supply_chain_schema")
# Out:
# DataFrame[]

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS retail_catalogss.supply_chain_schema")
spark.sql("create table retail_catalogsss.supply_chain_schema.retail_final_table using delta as select * from retail_final_delta")
# Out:
# DataFrame[num_affected_rows: bigint, num_inserted_rows: bigint]

# %%
spark.sql("create table retail_catalogsss.supply_chain_schema.category_revenue_table as select category,sum(bill_amount) as total_revenue from retail_catalogsss.supply_chain_schema.retail_final_table group by category")
# Out:
# DataFrame[num_affected_rows: bigint, num_inserted_rows: bigint]

# %%
spark.sql("describe history retail_catalogsss.supply_chain_schema.category_revenue_table").show()
# Out:
# +-------+-------------------+---------------+--------------------+--------------------+--------------------+----+----------------+-----------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# |version|          timestamp|         userId|            userName|           operation| operationParameters| job|        notebook|queryHistoryStatementId|           clusterId|readVersion|   isolationLevel|isBlindAppend|    operationMetrics|userMetadata|          engineInfo|
# +-------+-------------------+---------------+--------------------+--------------------+--------------------+----+----------------+-----------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# ...

# %%
spark.sql("grant select on table retail_catalogsss.supply_chain_schema.retail_final_table to `account users`")
# Out:
# DataFrame[]
