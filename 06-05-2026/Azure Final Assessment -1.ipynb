# %%
patients_data = [
(1001,"Aarav Khan","Hyderabad",29,"Male","Gold","2023-01-10"),
(1002,"Priya Reddy","Bengaluru",34,"Female","Silver","2023-01-15"),
(1003,"Rahul Mehta","Mumbai",41,"Male","Gold","2023-02-02"),
(1004,"Sneha Kapoor","Delhi",26,"Female","Bronze","2023-02-18"),
(1005,"Kiran Patel","Ahmedabad",37,"Male","Silver","2023-03-01"),
(1006,"Ananya Das","Kolkata",31,"Female","Gold","2023-03-12"),
(1007,"Vikram Singh","Chennai",45,"Male","Bronze","2023-03-20"),
(1008,"Meera Nair","Kochi",28,"Female","Silver","2023-04-05"),
(1009,"Farhan Ali","Hyderabad",39,"Male","Gold","2023-04-15"),
(1010,"Divya Menon","Bengaluru",33,"Female","Silver","2023-04-21"),
(1011,"Arjun Iyer","Chennai",52,"Male","Gold","2023-05-01"),
(1012,"Neha Gupta","Delhi",25,"Female","Bronze","2023-05-11"),
(1013,"Sanjay Rao","Mumbai",48,"Male","Silver","2023-05-19"),
(1014,"Kavya Sharma","Hyderabad",30,"Female","Gold","2023-06-01"),
(1015,"Nikhil Verma","Pune",36,"Male","Silver","2023-06-12"),
(1016,"Ayesha Khan","Kolkata",27,"Female","Bronze","2023-06-20"),
(1017,"Manish Yadav","Lucknow",44,"Male","Gold","2023-07-05"),
(1018,"Pooja Shah","Ahmedabad",32,"Female","Silver","2023-07-18"),
(1019,"Rohan Nair","Kochi",40,"Male","Gold","2023-08-01"),
(1020,"Lakshmi Rao","Chennai",35,"Female","Silver","2023-08-14")
]

patients_columns = [
"patient_id",
"patient_name",
"city",
"age",
"gender",
"membership",
"registration_date"
]

patients_df = spark.createDataFrame(
    patients_data,
    patients_columns
)

display(patients_df)

doctors_data = [
(201,"Dr Sameer Sharma","Cardiology","Hyderabad",1200),
(202,"Dr Kavita Iyer","Dermatology","Bengaluru",800),
(203,"Dr Imran Khan","Orthopedics","Mumbai",1500),
(204,"Dr Ramesh Reddy","Pediatrics","Delhi",900),
(205,"Dr Anita Mehta","Neurology","Hyderabad",2000),
(206,"Dr Joseph Mathew","Cardiology","Chennai",1300),
(207,"Dr Fatima Ali","Dermatology","Kolkata",850),
(208,"Dr Arvind Rao","Orthopedics","Bengaluru",1400),
(209,"Dr Leela Nair","Neurology","Kochi",1900),
(210,"Dr Ganesh Patil","General Medicine","Pune",700)
]

doctors_columns = [
"doctor_id",
"doctor_name",
"specialization",
"doctor_city",
"consultation_fee"
]

doctors_df = spark.createDataFrame(
    doctors_data,
    doctors_columns
)

display(doctors_df)

visits_data = [
(1,1001,201,"2024-03-01","Completed",2),
(2,1002,202,"2024-03-01","Completed",1),
(3,1003,203,"2024-03-02","Completed",3),
(4,1004,204,"2024-03-02","Pending",1),
(5,1005,206,"2024-03-03","Completed",2),
(6,1006,205,"2024-03-03","Completed",4),
(7,1007,207,"2024-03-04","Cancelled",1),
(8,1008,208,"2024-03-04","Completed",2),
(9,1009,201,"2024-03-05","Completed",1),
(10,1010,202,"2024-03-05","Completed",2),
(11,1011,205,"2024-03-06","Pending",3),
(12,1012,204,"2024-03-06","Completed",1),
(13,1013,203,"2024-03-07","Completed",2),
(14,1014,201,"2024-03-07","Completed",3),
(15,1015,210,"2024-03-08","Completed",1),
(16,1016,207,"2024-03-08","Cancelled",2),
(17,1017,209,"2024-03-09","Completed",4),
(18,1018,206,"2024-03-09","Completed",2),
(19,1019,209,"2024-03-10","Completed",3),
(20,1020,206,"2024-03-10","Pending",2),
(21,1001,205,"2024-03-11","Completed",3),
(22,1003,208,"2024-03-11","Completed",2),
(23,1006,201,"2024-03-12","Completed",1),
(24,1009,210,"2024-03-12","Completed",2),
(25,1014,202,"2024-03-13","Completed",1)
]

visits_columns = [
"visit_id",
"patient_id",
"doctor_id",
"visit_date",
"visit_status",
"tests_count"
]

visits_df = spark.createDataFrame(
    visits_data,
    visits_columns
)

display(visits_df)

payments_data = [
(301,1,5200,"UPI","Paid"),
(302,2,2800,"Credit Card","Paid"),
(303,3,7500,"Cash","Paid"),
(304,4,2900,"UPI","Pending"),
(305,5,5300,"Debit Card","Paid"),
(306,6,10000,"Credit Card","Paid"),
(307,7,2850,"Cash","Cancelled"),
(308,8,5400,"UPI","Paid"),
(309,9,3200,"UPI","Paid"),
(310,10,4800,"Credit Card","Paid"),
(311,11,8000,"UPI","Pending"),
(312,12,2900,"Cash","Paid"),
(313,13,5500,"Credit Card","Paid"),
(314,14,7200,"UPI","Paid"),
(315,15,2700,"Debit Card","Paid"),
(316,16,4850,"Cash","Cancelled"),
(317,17,9900,"Credit Card","Paid"),
(318,18,5300,"UPI","Paid"),
(319,19,7900,"Debit Card","Paid"),
(320,20,5300,"UPI","Pending"),
(321,21,8000,"UPI","Paid"),
(322,22,5400,"Credit Card","Paid"),
(323,23,3200,"Cash","Paid"),
(324,24,4700,"UPI","Paid"),
(325,25,2800,"UPI","Paid")
]

payments_columns = [
"payment_id",
"visit_id",
"bill_amount",
"payment_mode",
"payment_status"
]

payments_df = spark.createDataFrame(
    payments_data,
    payments_columns
)

display(payments_df)

daily_visits_data = [
(26,1002,201,"2024-03-14","Completed",2),
(27,1005,210,"2024-03-14","Completed",1),
(11,1011,205,"2024-03-06","Completed",3),
(20,1020,206,"2024-03-10","Completed",2),
(28,1018,203,"2024-03-15","Pending",2)
]

daily_visits_columns = [
"visit_id",
"patient_id",
"doctor_id",
"visit_date",
"visit_status",
"tests_count"
]

daily_visits_df = spark.createDataFrame(
    daily_visits_data,
    daily_visits_columns
)

display(daily_visits_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# PART -1

# %%
display(patients_df)
display(doctors_df)
display(visits_df)
display(payments_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
patients_df.printSchema()
doctors_df.printSchema()
visits_df.printSchema()
payments_df.printSchema()
# Out:
# root
#  |-- patient_id: long (nullable = true)
#  |-- patient_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- age: long (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- membership: string (nullable = true)
#  |-- registration_date: string (nullable = true)
#
# root
#  |-- doctor_id: long (nullable = true)
#  |-- doctor_name: string (nullable = true)
#  |-- specialization: string (nullable = true)
#  |-- doctor_city: string (nullable = true)
#  |-- consultation_fee: long (nullable = true)
#
# root
#  |-- visit_id: long (nullable = true)
#  |-- patient_id: long (nullable = true)
#  |-- doctor_id: long (nullable = true)
#  |-- visit_date: string (nullable = true)
#  |-- visit_status: string (nullable = true)
#  |-- tests_count: long (nullable = true)
#
# root
#  |-- payment_id: long (nullable = true)
#  |-- visit_id: long (nullable = true)
#  |-- bill_amount: long (nullable = true)
#  |-- payment_mode: string (nullable = true)
# ...

# %%
patients_df.count()
doctors_df.count()
visits_df.count()
payments_df.count()
# Out:
# 25

# %%
patients_df.show(10)
# Out:
# +----------+------------+---------+---+------+----------+-----------------+
# |patient_id|patient_name|     city|age|gender|membership|registration_date|
# +----------+------------+---------+---+------+----------+-----------------+
# |      1001|  Aarav Khan|Hyderabad| 29|  Male|      Gold|       2023-01-10|
# |      1002| Priya Reddy|Bengaluru| 34|Female|    Silver|       2023-01-15|
# |      1003| Rahul Mehta|   Mumbai| 41|  Male|      Gold|       2023-02-02|
# |      1004|Sneha Kapoor|    Delhi| 26|Female|    Bronze|       2023-02-18|
# |      1005| Kiran Patel|Ahmedabad| 37|  Male|    Silver|       2023-03-01|
# |      1006|  Ananya Das|  Kolkata| 31|Female|      Gold|       2023-03-12|
# |      1007|Vikram Singh|  Chennai| 45|  Male|    Bronze|       2023-03-20|
# |      1008|  Meera Nair|    Kochi| 28|Female|    Silver|       2023-04-05|
# |      1009|  Farhan Ali|Hyderabad| 39|  Male|      Gold|       2023-04-15|
# ...

# %%
patients_df.select("patient_name","city","membership","age").show()
# Out:
# +------------+---------+----------+---+
# |patient_name|     city|membership|age|
# +------------+---------+----------+---+
# |  Aarav Khan|Hyderabad|      Gold| 29|
# | Priya Reddy|Bengaluru|    Silver| 34|
# | Rahul Mehta|   Mumbai|      Gold| 41|
# |Sneha Kapoor|    Delhi|    Bronze| 26|
# | Kiran Patel|Ahmedabad|    Silver| 37|
# |  Ananya Das|  Kolkata|      Gold| 31|
# |Vikram Singh|  Chennai|    Bronze| 45|
# |  Meera Nair|    Kochi|    Silver| 28|
# |  Farhan Ali|Hyderabad|      Gold| 39|
# | Divya Menon|Bengaluru|    Silver| 33|
# |  Arjun Iyer|  Chennai|      Gold| 52|
# |  Neha Gupta|    Delhi|    Bronze| 25|
# |  Sanjay Rao|   Mumbai|    Silver| 48|
# |Kavya Sharma|Hyderabad|      Gold| 30|
# |Nikhil Verma|     Pune|    Silver| 36|
# | Ayesha Khan|  Kolkata|    Bronze| 27|
# |Manish Yadav|  Lucknow|      Gold| 44|
# |  Pooja Shah|Ahmedabad|    Silver| 32|
# |  Rohan Nair|    Kochi|      Gold| 40|
# | Lakshmi Rao|  Chennai|    Silver| 35|
# ...

# %%
doctors_df.select("doctor_name","specialization","consultation_fee").show()
# Out:
# +----------------+----------------+----------------+
# |     doctor_name|  specialization|consultation_fee|
# +----------------+----------------+----------------+
# |Dr Sameer Sharma|      Cardiology|            1200|
# |  Dr Kavita Iyer|     Dermatology|             800|
# |   Dr Imran Khan|     Orthopedics|            1500|
# | Dr Ramesh Reddy|      Pediatrics|             900|
# |  Dr Anita Mehta|       Neurology|            2000|
# |Dr Joseph Mathew|      Cardiology|            1300|
# |   Dr Fatima Ali|     Dermatology|             850|
# |   Dr Arvind Rao|     Orthopedics|            1400|
# |   Dr Leela Nair|       Neurology|            1900|
# | Dr Ganesh Patil|General Medicine|             700|
# +----------------+----------------+----------------+

# %%
visits_df.filter(visits_df.visit_status=="Completed").show()
# Out:
# +--------+----------+---------+----------+------------+-----------+
# |visit_id|patient_id|doctor_id|visit_date|visit_status|tests_count|
# +--------+----------+---------+----------+------------+-----------+
# |       1|      1001|      201|2024-03-01|   Completed|          2|
# |       2|      1002|      202|2024-03-01|   Completed|          1|
# |       3|      1003|      203|2024-03-02|   Completed|          3|
# |       5|      1005|      206|2024-03-03|   Completed|          2|
# |       6|      1006|      205|2024-03-03|   Completed|          4|
# |       8|      1008|      208|2024-03-04|   Completed|          2|
# |       9|      1009|      201|2024-03-05|   Completed|          1|
# |      10|      1010|      202|2024-03-05|   Completed|          2|
# |      12|      1012|      204|2024-03-06|   Completed|          1|
# |      13|      1013|      203|2024-03-07|   Completed|          2|
# |      14|      1014|      201|2024-03-07|   Completed|          3|
# ...

# %%
visits_df.filter(visits_df.visit_status=="Pending").show()
# Out:
# +--------+----------+---------+----------+------------+-----------+
# |visit_id|patient_id|doctor_id|visit_date|visit_status|tests_count|
# +--------+----------+---------+----------+------------+-----------+
# |       4|      1004|      204|2024-03-02|     Pending|          1|
# |      11|      1011|      205|2024-03-06|     Pending|          3|
# |      20|      1020|      206|2024-03-10|     Pending|          2|
# +--------+----------+---------+----------+------------+-----------+

# %%
patients_df.filter(patients_df.city.isin("Hyderabad","Bengaluru")).show()
# Out:
# +----------+------------+---------+---+------+----------+-----------------+
# |patient_id|patient_name|     city|age|gender|membership|registration_date|
# +----------+------------+---------+---+------+----------+-----------------+
# |      1001|  Aarav Khan|Hyderabad| 29|  Male|      Gold|       2023-01-10|
# |      1002| Priya Reddy|Bengaluru| 34|Female|    Silver|       2023-01-15|
# |      1009|  Farhan Ali|Hyderabad| 39|  Male|      Gold|       2023-04-15|
# |      1010| Divya Menon|Bengaluru| 33|Female|    Silver|       2023-04-21|
# |      1014|Kavya Sharma|Hyderabad| 30|Female|      Gold|       2023-06-01|
# +----------+------------+---------+---+------+----------+-----------------+

# %%
doctors_df.filter(doctors_df.consultation_fee>1000).show()
# Out:
# +---------+----------------+--------------+-----------+----------------+
# |doctor_id|     doctor_name|specialization|doctor_city|consultation_fee|
# +---------+----------------+--------------+-----------+----------------+
# |      201|Dr Sameer Sharma|    Cardiology|  Hyderabad|            1200|
# |      203|   Dr Imran Khan|   Orthopedics|     Mumbai|            1500|
# |      205|  Dr Anita Mehta|     Neurology|  Hyderabad|            2000|
# |      206|Dr Joseph Mathew|    Cardiology|    Chennai|            1300|
# |      208|   Dr Arvind Rao|   Orthopedics|  Bengaluru|            1400|
# |      209|   Dr Leela Nair|     Neurology|      Kochi|            1900|
# +---------+----------------+--------------+-----------+----------------+

# %% [markdown]
# PART-2

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import*

# %%
patients_df=patients_df.withColumn("registration_date",to_date(col("registration_date"),"yyyy-MM-dd"))
patients_df.printSchema()
# Out:
# root
#  |-- patient_id: long (nullable = true)
#  |-- patient_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- age: long (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- membership: string (nullable = true)
#  |-- registration_date: date (nullable = true)

# %%
visits_df=visits_df.withColumn("visit_date",to_date(col("visit_date"),"yyyy-MM-dd"))
visits_df.printSchema()
# Out:
# root
#  |-- visit_id: long (nullable = true)
#  |-- patient_id: long (nullable = true)
#  |-- doctor_id: long (nullable = true)
#  |-- visit_date: date (nullable = true)
#  |-- visit_status: string (nullable = true)
#  |-- tests_count: long (nullable = true)

# %%
visits_df=visits_df.withColumn("test_cost",col("tests_count")*500)
display(visits_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
visits_df=visits_df.withColumn("estimated_total_bill",col("tests_count")+2000)
display(visits_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
patients_df=patients_df.withColumn("age_category",when(col("age")<30,"Young").when(col("age")<45,"Adult").otherwise("Senior"))
display(patients_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
patients_df=patients_df.withColumn("membership_priority",when(col("membership")=="Gold",1).when(col("membership")=="Silver",2).otherwise(3))
display(patients_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
visits_df=visits_df.withColumn("visit_priority",when(col("visit_status")=="Completed","High").when(col("visit_status")=="Pending","Mediuim").otherwise("Low"))
display(visits_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
payments_df=payments_df.withColumn("high_bill_flag",when(col("bill_amount")>7000,"Yes").otherwise("No"))
display(payments_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
patients_df=patients_df.withColumnRenamed("patient_name","full_name")
display(patients_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
visits_df=visits_df.drop("test_cost")
display(visits_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# PART-3

# %%
from pyspark.sql.functions import *

# %%
patients_visits_df=patients_df.join(visits_df,on="patient_id",how="inner")
display(patients_visits_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
visit_doctor_df=visits_df.join(doctors_df,on="doctor_id",how="inner")
display(visit_doctor_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
visit_payment_df=visits_df.join(payments_df,on="visit_id",how="inner")
display(visit_payment_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
final_df=patients_df.join(visits_df,on="patient_id",how="inner").join(doctors_df,on="doctor_id",how="inner").join(payments_df,on="visit_id",how="inner")
display(final_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
final_df.select("full_name","city","doctor_name","specialization","visit_status","bill_amount").show()
# Out:
# +------------+---------+----------------+----------------+------------+-----------+
# |   full_name|     city|     doctor_name|  specialization|visit_status|bill_amount|
# +------------+---------+----------------+----------------+------------+-----------+
# |  Aarav Khan|Hyderabad|Dr Sameer Sharma|      Cardiology|   Completed|       5200|
# | Priya Reddy|Bengaluru|  Dr Kavita Iyer|     Dermatology|   Completed|       2800|
# | Rahul Mehta|   Mumbai|   Dr Imran Khan|     Orthopedics|   Completed|       7500|
# |Sneha Kapoor|    Delhi| Dr Ramesh Reddy|      Pediatrics|     Pending|       2900|
# | Kiran Patel|Ahmedabad|Dr Joseph Mathew|      Cardiology|   Completed|       5300|
# |  Ananya Das|  Kolkata|  Dr Anita Mehta|       Neurology|   Completed|      10000|
# |Vikram Singh|  Chennai|   Dr Fatima Ali|     Dermatology|   Cancelled|       2850|
# |  Meera Nair|    Kochi|   Dr Arvind Rao|     Orthopedics|   Completed|       5400|
# ...

# %%
final_df.filter(col("city")!=col("doctor_city")).select("full_name","city","doctor_name","doctor_city").show()
# Out:
# +------------+---------+----------------+-----------+
# |   full_name|     city|     doctor_name|doctor_city|
# +------------+---------+----------------+-----------+
# | Kiran Patel|Ahmedabad|Dr Joseph Mathew|    Chennai|
# |  Ananya Das|  Kolkata|  Dr Anita Mehta|  Hyderabad|
# |Vikram Singh|  Chennai|   Dr Fatima Ali|    Kolkata|
# |  Meera Nair|    Kochi|   Dr Arvind Rao|  Bengaluru|
# |  Arjun Iyer|  Chennai|  Dr Anita Mehta|  Hyderabad|
# |Manish Yadav|  Lucknow|   Dr Leela Nair|      Kochi|
# |  Pooja Shah|Ahmedabad|Dr Joseph Mathew|    Chennai|
# | Rahul Mehta|   Mumbai|   Dr Arvind Rao|  Bengaluru|
# |  Ananya Das|  Kolkata|Dr Sameer Sharma|  Hyderabad|
# |  Farhan Ali|Hyderabad| Dr Ganesh Patil|       Pune|
# |Kavya Sharma|Hyderabad|  Dr Kavita Iyer|  Bengaluru|
# +------------+---------+----------------+-----------+

# %%
final_df.filter((col("visit_status")=="Completed")&(col("payment_status")=="Paid")).show()
# Out:
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+
# |visit_id|doctor_id|patient_id|   full_name|     city|age|gender|membership|registration_date|age_category|membership_priority|visit_date|visit_status|tests_count|estimated_total_bill|visit_priority|     doctor_name|  specialization|doctor_city|consultation_fee|payment_id|bill_amount|payment_mode|payment_status|high_bill_flag|
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+
# ...

# %%
final_df.filter((col("visit_status")=="Pending")&(col("payment_status")=="Pending")).show()
# Out:
# +--------+---------+----------+------------+-------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+--------------+-----------+----------------+----------+-----------+------------+--------------+--------------+
# |visit_id|doctor_id|patient_id|   full_name|   city|age|gender|membership|registration_date|age_category|membership_priority|visit_date|visit_status|tests_count|estimated_total_bill|visit_priority|     doctor_name|specialization|doctor_city|consultation_fee|payment_id|bill_amount|payment_mode|payment_status|high_bill_flag|
# +--------+---------+----------+------------+-------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+--------------+-----------+----------------+----------+-----------+------------+--------------+--------------+
# ...

# %%
final_df.filter((col("visit_status")=="Cancelled")&(col("payment_status")=="Cancelled")).show()
# Out:
# +--------+---------+----------+------------+-------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+-------------+--------------+-----------+----------------+----------+-----------+------------+--------------+--------------+
# |visit_id|doctor_id|patient_id|   full_name|   city|age|gender|membership|registration_date|age_category|membership_priority|visit_date|visit_status|tests_count|estimated_total_bill|visit_priority|  doctor_name|specialization|doctor_city|consultation_fee|payment_id|bill_amount|payment_mode|payment_status|high_bill_flag|
# +--------+---------+----------+------------+-------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+-------------+--------------+-----------+----------------+----------+-----------+------------+--------------+--------------+
# ...

# %%
final_df.groupBy("patient_id","full_name").count().filter(col("count")>1).show()
# Out:
# +----------+------------+-----+
# |patient_id|   full_name|count|
# +----------+------------+-----+
# |      1001|  Aarav Khan|    2|
# |      1003| Rahul Mehta|    2|
# |      1006|  Ananya Das|    2|
# |      1009|  Farhan Ali|    2|
# |      1014|Kavya Sharma|    2|
# +----------+------------+-----+

# %% [markdown]
# PART-4

# %%
from pyspark.sql.functions import *

# %%
patients_df.groupBy("city").count().show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Hyderabad|    3|
# |Bengaluru|    2|
# |   Mumbai|    2|
# |    Delhi|    2|
# |Ahmedabad|    2|
# |  Kolkata|    2|
# |  Chennai|    3|
# |    Kochi|    2|
# |     Pune|    1|
# |  Lucknow|    1|
# +---------+-----+

# %%
patients_df.groupBy("membership").count().show()
# Out:
# +----------+-----+
# |membership|count|
# +----------+-----+
# |      Gold|    8|
# |    Silver|    8|
# |    Bronze|    4|
# +----------+-----+

# %%
doctors_df.groupBy("specialization").count().show()
# Out:
# +----------------+-----+
# |  specialization|count|
# +----------------+-----+
# |      Cardiology|    2|
# |     Dermatology|    2|
# |     Orthopedics|    2|
# |      Pediatrics|    1|
# |       Neurology|    2|
# |General Medicine|    1|
# +----------------+-----+

# %%
visits_df.groupBy("visit_status").count().show()
# Out:
# +------------+-----+
# |visit_status|count|
# +------------+-----+
# |   Completed|   20|
# |     Pending|    3|
# |   Cancelled|    2|
# +------------+-----+

# %%
payments_df.groupBy("payment_mode").count().show()
# Out:
# +------------+-----+
# |payment_mode|count|
# +------------+-----+
# |         UPI|   11|
# | Credit Card|    6|
# |        Cash|    5|
# |  Debit Card|    3|
# +------------+-----+

# %%
payments_df.select(sum("bill_amount").alias("total_bill_amount")).show()
# Out:
# +-----------------+
# |total_bill_amount|
# +-----------------+
# |           133600|
# +-----------------+

# %%
payments_df.select(avg("bill_amount").alias("average_bill_amount")).show()
# Out:
# +-------------------+
# |average_bill_amount|
# +-------------------+
# |             5344.0|
# +-------------------+

# %%
final_df.groupBy("city").agg(sum("bill_amount").alias("total_revenue")).show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Hyderabad|        31100|
# |   Mumbai|        18400|
# |Bengaluru|         7600|
# |    Delhi|         5800|
# |Ahmedabad|        10600|
# |  Kolkata|        18050|
# |  Chennai|        16150|
# |    Kochi|        13300|
# |     Pune|         2700|
# |  Lucknow|         9900|
# +---------+-------------+

# %%
final_df.groupBy("specialization").agg(sum("bill_amount").alias("total_revenue")).show()
# Out:
# +----------------+-------------+
# |  specialization|total_revenue|
# +----------------+-------------+
# |     Orthopedics|        23800|
# |      Cardiology|        34700|
# |     Dermatology|        18100|
# |      Pediatrics|         5800|
# |       Neurology|        43800|
# |General Medicine|         7400|
# +----------------+-------------+

# %%
final_df.groupBy("doctor_name").agg(sum("bill_amount").alias("total_revenue")).show()
# Out:
# +----------------+-------------+
# |     doctor_name|total_revenue|
# +----------------+-------------+
# |   Dr Imran Khan|        13000|
# |  Dr Kavita Iyer|        10400|
# |Dr Sameer Sharma|        18800|
# |  Dr Anita Mehta|        26000|
# |Dr Joseph Mathew|        15900|
# | Dr Ramesh Reddy|         5800|
# |   Dr Arvind Rao|        10800|
# |   Dr Fatima Ali|         7700|
# | Dr Ganesh Patil|         7400|
# |   Dr Leela Nair|        17800|
# +----------------+-------------+

# %% [markdown]
# PART-5

# %%
patients_df.createOrReplaceTempView("patients")
doctors_df.createOrReplaceTempView("doctors")
visits_df.createOrReplaceTempView("visits")
payments_df.createOrReplaceTempView("payments")
final_df.createOrReplaceTempView("final_table")

# %%
spark.sql("""SELECT * FROM patients""").show()
# Out:
# +----------+------------+---------+---+------+----------+-----------------+------------+-------------------+
# |patient_id|   full_name|     city|age|gender|membership|registration_date|age_category|membership_priority|
# +----------+------------+---------+---+------+----------+-----------------+------------+-------------------+
# |      1001|  Aarav Khan|Hyderabad| 29|  Male|      Gold|       2023-01-10|       Young|                  1|
# |      1002| Priya Reddy|Bengaluru| 34|Female|    Silver|       2023-01-15|       Adult|                  2|
# |      1003| Rahul Mehta|   Mumbai| 41|  Male|      Gold|       2023-02-02|       Adult|                  1|
# |      1004|Sneha Kapoor|    Delhi| 26|Female|    Bronze|       2023-02-18|       Young|                  3|
# |      1005| Kiran Patel|Ahmedabad| 37|  Male|    Silver|       2023-03-01|       Adult|                  2|
# |      1006|  Ananya Das|  Kolkata| 31|Female|      Gold|       2023-03-12|       Adult|                  1|
# ...

# %%
spark.sql("""SELECT f.full_name,f.doctor_name,f.specialization,f.visit_status FROM final_table f WHERE specialization='Cardiology' """).show()
# Out:
# +------------+----------------+--------------+------------+
# |   full_name|     doctor_name|specialization|visit_status|
# +------------+----------------+--------------+------------+
# |  Aarav Khan|Dr Sameer Sharma|    Cardiology|   Completed|
# | Kiran Patel|Dr Joseph Mathew|    Cardiology|   Completed|
# |  Farhan Ali|Dr Sameer Sharma|    Cardiology|   Completed|
# |Kavya Sharma|Dr Sameer Sharma|    Cardiology|   Completed|
# |  Pooja Shah|Dr Joseph Mathew|    Cardiology|   Completed|
# | Lakshmi Rao|Dr Joseph Mathew|    Cardiology|     Pending|
# |  Ananya Das|Dr Sameer Sharma|    Cardiology|   Completed|
# +------------+----------------+--------------+------------+

# %%
spark.sql("""SELECT city,SUM(bill_amount) AS total_revenue FROM final_table GROUP BY city""").show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Hyderabad|        31100|
# |   Mumbai|        18400|
# |Bengaluru|         7600|
# |    Delhi|         5800|
# |Ahmedabad|        10600|
# |  Kolkata|        18050|
# |  Chennai|        16150|
# |    Kochi|        13300|
# |     Pune|         2700|
# |  Lucknow|         9900|
# +---------+-------------+

# %%
spark.sql(""" SELECT specialization,SUM(bill_amount) AS total_revenue FROM final_table GROUP BY specialization""").show()
# Out:
# +----------------+-------------+
# |  specialization|total_revenue|
# +----------------+-------------+
# |     Orthopedics|        23800|
# |      Cardiology|        34700|
# |     Dermatology|        18100|
# |      Pediatrics|         5800|
# |       Neurology|        43800|
# |General Medicine|         7400|
# +----------------+-------------+

# %%
spark.sql(""" SELECT visit_id,full_name,bill_amount FROM final_table ORDER BY bill_amount DESC LIMIT 5""").show()
# Out:
# +--------+------------+-----------+
# |visit_id|   full_name|bill_amount|
# +--------+------------+-----------+
# |       6|  Ananya Das|      10000|
# |      17|Manish Yadav|       9900|
# |      11|  Arjun Iyer|       8000|
# |      21|  Aarav Khan|       8000|
# |      19|  Rohan Nair|       7900|
# +--------+------------+-----------+

# %%
spark.sql(""" SELECT doctor_name,COUNT(visit_id) AS total_visits FROM final_table GROUP BY doctor_name""").show()
# Out:
# +----------------+------------+
# |     doctor_name|total_visits|
# +----------------+------------+
# |   Dr Imran Khan|           2|
# |  Dr Kavita Iyer|           3|
# |Dr Sameer Sharma|           4|
# |  Dr Anita Mehta|           3|
# |Dr Joseph Mathew|           3|
# | Dr Ramesh Reddy|           2|
# |   Dr Arvind Rao|           2|
# |   Dr Fatima Ali|           2|
# | Dr Ganesh Patil|           2|
# |   Dr Leela Nair|           2|
# +----------------+------------+

# %%
spark.sql(""" SELECT full_name,COUNT(visit_id) as total_visits FROM final_table GROUP BY full_name""").show()
# Out:
# +------------+------------+
# |   full_name|total_visits|
# +------------+------------+
# | Rahul Mehta|           2|
# |  Aarav Khan|           2|
# | Priya Reddy|           1|
# |Sneha Kapoor|           1|
# | Kiran Patel|           1|
# |  Ananya Das|           2|
# |Vikram Singh|           1|
# |  Farhan Ali|           2|
# |  Meera Nair|           1|
# | Divya Menon|           1|
# |  Neha Gupta|           1|
# |  Arjun Iyer|           1|
# |Nikhil Verma|           1|
# |Kavya Sharma|           2|
# |  Sanjay Rao|           1|
# | Ayesha Khan|           1|
# |Manish Yadav|           1|
# |  Pooja Shah|           1|
# |  Rohan Nair|           1|
# | Lakshmi Rao|           1|
# +------------+------------+

# %%
spark.sql("""SELECT payment_mode,AVG(bill_amount) AS average_bill FROM  final_table GROUP BY payment_mode""").show()
# Out:
# +------------+-----------------+
# |payment_mode|     average_bill|
# +------------+-----------------+
# | Credit Card|           6400.0|
# |         UPI|5272.727272727273|
# |        Cash|           4260.0|
# |  Debit Card|           5300.0|
# +------------+-----------------+

# %%
spark.sql("""SELECT full_name,SUM(bill_amount) AS total_bill FROM final_table GROUP BY full_name HAVING SUM(bill_amount)>10000""").show()
# Out:
# +-----------+----------+
# |  full_name|total_bill|
# +-----------+----------+
# |Rahul Mehta|     12900|
# | Aarav Khan|     13200|
# | Ananya Das|     13200|
# +-----------+----------+

# %% [markdown]
# PART-6

# %%
from pyspark.sql.window import Window 
from pyspark.sql.functions import*

# %%
from pyspark.sql.window import Window
patient_bill_df=final_df.groupBy("city","full_name").sum("bill_amount")
window_spec=Window.partitionBy("city").orderBy(col("sum(bill_amount)").desc())
patient_bill_df.withColumn("rank",rank().over(window_spec)).show()
# Out:
# +---------+------------+----------------+----+
# |     city|   full_name|sum(bill_amount)|rank|
# +---------+------------+----------------+----+
# |Ahmedabad| Kiran Patel|            5300|   1|
# |Ahmedabad|  Pooja Shah|            5300|   1|
# |Bengaluru| Divya Menon|            4800|   1|
# |Bengaluru| Priya Reddy|            2800|   2|
# |  Chennai|  Arjun Iyer|            8000|   1|
# |  Chennai| Lakshmi Rao|            5300|   2|
# |  Chennai|Vikram Singh|            2850|   3|
# |    Delhi|Sneha Kapoor|            2900|   1|
# |    Delhi|  Neha Gupta|            2900|   1|
# |Hyderabad|  Aarav Khan|           13200|   1|
# |Hyderabad|Kavya Sharma|           10000|   2|
# |Hyderabad|  Farhan Ali|            7900|   3|
# |    Kochi|  Rohan Nair|            7900|   1|
# |    Kochi|  Meera Nair|            5400|   2|
# |  Kolkata|  Ananya Das|           13200|   1|
# |  Kolkata| Ayesha Khan|            4850|   2|
# |  Lucknow|Manish Yadav|            9900|   1|
# ...

# %%
doctor_revenue_df=final_df.groupBy("specialization","doctor_name").sum("bill_amount")
window_spec=Window.partitionBy("specialization").orderBy(col("sum(bill_amount)").desc())
doctor_revenue_df.withColumn("rank",rank().over(window_spec)).show()
# Out:
# +----------------+----------------+----------------+----+
# |  specialization|     doctor_name|sum(bill_amount)|rank|
# +----------------+----------------+----------------+----+
# |      Cardiology|Dr Sameer Sharma|           18800|   1|
# |      Cardiology|Dr Joseph Mathew|           15900|   2|
# |     Dermatology|  Dr Kavita Iyer|           10400|   1|
# |     Dermatology|   Dr Fatima Ali|            7700|   2|
# |General Medicine| Dr Ganesh Patil|            7400|   1|
# |       Neurology|  Dr Anita Mehta|           26000|   1|
# |       Neurology|   Dr Leela Nair|           17800|   2|
# |     Orthopedics|   Dr Imran Khan|           13000|   1|
# |     Orthopedics|   Dr Arvind Rao|           10800|   2|
# |      Pediatrics| Dr Ramesh Reddy|            5800|   1|
# +----------------+----------------+----------------+----+

# %%
patient_bill_df=final_df.groupBy("city","full_name").sum("bill_amount")
window_spec=Window.partitionBy("city").orderBy(col("sum(bill_amount)").desc())
patient_bill_df.withColumn("row_num",row_number().over(window_spec)).filter(col("row_num")==1).show()
# Out:
# +---------+------------+----------------+-------+
# |     city|   full_name|sum(bill_amount)|row_num|
# +---------+------------+----------------+-------+
# |Ahmedabad| Kiran Patel|            5300|      1|
# |Bengaluru| Divya Menon|            4800|      1|
# |  Chennai|  Arjun Iyer|            8000|      1|
# |    Delhi|Sneha Kapoor|            2900|      1|
# |Hyderabad|  Aarav Khan|           13200|      1|
# |    Kochi|  Rohan Nair|            7900|      1|
# |  Kolkata|  Ananya Das|           13200|      1|
# |  Lucknow|Manish Yadav|            9900|      1|
# |   Mumbai| Rahul Mehta|           12900|      1|
# |     Pune|Nikhil Verma|            2700|      1|
# +---------+------------+----------------+-------+

# %%
window_spec=Window.partitionBy("specialization").orderBy(col("consultation_fee").desc())
doctors_df.withColumn("dense_rank",dense_rank().over(window_spec)).show()
# Out:
# +---------+----------------+----------------+-----------+----------------+----------+
# |doctor_id|     doctor_name|  specialization|doctor_city|consultation_fee|dense_rank|
# +---------+----------------+----------------+-----------+----------------+----------+
# |      206|Dr Joseph Mathew|      Cardiology|    Chennai|            1300|         1|
# |      201|Dr Sameer Sharma|      Cardiology|  Hyderabad|            1200|         2|
# |      207|   Dr Fatima Ali|     Dermatology|    Kolkata|             850|         1|
# |      202|  Dr Kavita Iyer|     Dermatology|  Bengaluru|             800|         2|
# |      210| Dr Ganesh Patil|General Medicine|       Pune|             700|         1|
# |      205|  Dr Anita Mehta|       Neurology|  Hyderabad|            2000|         1|
# |      209|   Dr Leela Nair|       Neurology|      Kochi|            1900|         2|
# |      203|   Dr Imran Khan|     Orthopedics|     Mumbai|            1500|         1|
# ...

# %%
doctor_revenue_df=final_df.groupBy("doctor_name").sum("bill_amount")
window_spec=Window.orderBy(col("sum(bill_amount)").desc())
doctor_revenue_df.withColumn("rank",rank().over(window_spec)).filter(col("rank")<=2).show()
# Out:
# +----------------+----------------+----+
# |     doctor_name|sum(bill_amount)|rank|
# +----------------+----------------+----+
# |  Dr Anita Mehta|           26000|   1|
# |Dr Sameer Sharma|           18800|   2|
# +----------------+----------------+----+

# %%
revenue_df=final_df.groupBy("visit_date").sum("bill_amount")
window_spec=Window.orderBy("visit_date")
revenue_df.withColumn("running_total",sum("sum(bill_amount)").over(window_spec)).show()
# Out:
# +----------+----------------+-------------+
# |visit_date|sum(bill_amount)|running_total|
# +----------+----------------+-------------+
# |2024-03-01|            8000|         8000|
# |2024-03-02|           10400|        18400|
# |2024-03-03|           15300|        33700|
# |2024-03-04|            8250|        41950|
# |2024-03-05|            8000|        49950|
# |2024-03-06|           10900|        60850|
# |2024-03-07|           12700|        73550|
# |2024-03-08|            7550|        81100|
# |2024-03-09|           15200|        96300|
# |2024-03-10|           13200|       109500|
# |2024-03-11|           13400|       122900|
# |2024-03-12|            7900|       130800|
# |2024-03-13|            2800|       133600|
# +----------+----------------+-------------+

# %%
doctor_df=final_df.groupBy("doctor_name","visit_date").sum("bill_amount")
window_spec=Window.partitionBy("doctor_name").orderBy("visit_date")
doctor_df.withColumn("running_total",sum("sum(bill_amount)").over(window_spec)).show()
# Out:
# +----------------+----------+----------------+-------------+
# |     doctor_name|visit_date|sum(bill_amount)|running_total|
# +----------------+----------+----------------+-------------+
# |  Dr Anita Mehta|2024-03-03|           10000|        10000|
# |  Dr Anita Mehta|2024-03-06|            8000|        18000|
# |  Dr Anita Mehta|2024-03-11|            8000|        26000|
# |   Dr Arvind Rao|2024-03-04|            5400|         5400|
# |   Dr Arvind Rao|2024-03-11|            5400|        10800|
# |   Dr Fatima Ali|2024-03-04|            2850|         2850|
# |   Dr Fatima Ali|2024-03-08|            4850|         7700|
# | Dr Ganesh Patil|2024-03-08|            2700|         2700|
# | Dr Ganesh Patil|2024-03-12|            4700|         7400|
# |   Dr Imran Khan|2024-03-02|            7500|         7500|
# |   Dr Imran Khan|2024-03-07|            5500|        13000|
# |Dr Joseph Mathew|2024-03-03|            5300|         5300|
# ...

# %%
city_revenue_df=final_df.groupBy("city").sum("bill_amount")
window_spec=Window.orderBy(col("sum(bill_amount)").desc())
city_revenue_df.withColumn("rank",rank().over(window_spec)).show()
# Out:
# +---------+----------------+----+
# |     city|sum(bill_amount)|rank|
# +---------+----------------+----+
# |Hyderabad|           31100|   1|
# |   Mumbai|           18400|   2|
# |  Kolkata|           18050|   3|
# |  Chennai|           16150|   4|
# |    Kochi|           13300|   5|
# |Ahmedabad|           10600|   6|
# |  Lucknow|            9900|   7|
# |Bengaluru|            7600|   8|
# |    Delhi|            5800|   9|
# |     Pune|            2700|  10|
# +---------+----------------+----+

# %%
specialization_df=final_df.groupBy("specialization").sum("bill_amount")
window_spec=Window.orderBy(col("sum(bill_amount)").desc())
specialization_df.withColumn("rank",rank().over(window_spec)).show()
# Out:
# +----------------+----------------+----+
# |  specialization|sum(bill_amount)|rank|
# +----------------+----------------+----+
# |       Neurology|           43800|   1|
# |      Cardiology|           34700|   2|
# |     Orthopedics|           23800|   3|
# |     Dermatology|           18100|   4|
# |General Medicine|            7400|   5|
# |      Pediatrics|            5800|   6|
# +----------------+----------------+----+

# %%
window_spec=Window.partitionBy("payment_mode").orderBy(col("bill_amount").desc())
payments_df.withColumn("rank",row_number().over(window_spec)).filter(col("rank")==1).show()
# Out:
# +----------+--------+-----------+------------+--------------+--------------+----+
# |payment_id|visit_id|bill_amount|payment_mode|payment_status|high_bill_flag|rank|
# +----------+--------+-----------+------------+--------------+--------------+----+
# |       303|       3|       7500|        Cash|          Paid|           Yes|   1|
# |       306|       6|      10000| Credit Card|          Paid|           Yes|   1|
# |       319|      19|       7900|  Debit Card|          Paid|           Yes|   1|
# |       311|      11|       8000|         UPI|       Pending|           Yes|   1|
# +----------+--------+-----------+------------+--------------+--------------+----+

# %% [markdown]
# PART -7

# %%
from delta.tables import DeltaTable 
from pyspark.sql.functions import *

# %%
final_df.write.format("delta").mode("overwrite").saveAsTable("hospital_final_delta")

# %%
new_visits_data=[(26,1002,201,"2024-03-14","Completed",2),(27,1005,210,"2024-03-14","Completed",1)]
new_visits_columns=["visit_id","patient_id","doctor_id","visit_date","visit_status","tests_count"]
new_visits_df=spark.createDataFrame(new_visits_data,new_visits_columns)
new_visits_df=new_visits_df.withColumn("visit_date",to_date(col("visit_date"),"yyyy-MM-dd"))
new_visits_df.write.format("delta").mode("append").option("mergeSchema","true").saveAsTable("hospital_final_delta")

# %%
spark.sql("update hospital_final_delta set visit_status='Completed' where visit_id=11")
# Out:
# DataFrame[num_affected_rows: bigint]

# %%
spark.sql("update hospital_final_delta set payment_status='Paid' where payment_status='Pending'")
# Out:
# DataFrame[num_affected_rows: bigint]

# %%
spark.sql("delete from hospital_final_delta where visit_status='Cancelled'")
# Out:
# DataFrame[num_affected_rows: bigint]

# %%
completed_df=final_df.filter(col("visit_status")=="Completed")
completed_df.write.format("delta").mode("overwrite").saveAsTable("completed_visits_delta")

# %%
spark.sql("describe history hospital_final_delta").show()
# Out:
# +-------+-------------------+---------------+--------------------+--------------------+--------------------+----+------------------+-----------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# |version|          timestamp|         userId|            userName|           operation| operationParameters| job|          notebook|queryHistoryStatementId|           clusterId|readVersion|   isolationLevel|isBlindAppend|    operationMetrics|userMetadata|          engineInfo|
# +-------+-------------------+---------------+--------------------+--------------------+--------------------+----+------------------+-----------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# ...

# %%
spark.read.format("delta").option("versionAsOf",0).table("hospital_final_delta").show()
# Out:
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+
# |visit_id|doctor_id|patient_id|   full_name|     city|age|gender|membership|registration_date|age_category|membership_priority|visit_date|visit_status|tests_count|estimated_total_bill|visit_priority|     doctor_name|  specialization|doctor_city|consultation_fee|payment_id|bill_amount|payment_mode|payment_status|high_bill_flag|
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+
# ...

# %%
latest_df=spark.read.format("delta").table("hospital_final_delta")
old_df=spark.read.format("delta").option("versionAsOf",0).table("hospital_final_delta")
display(latest_df)
display(old_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
spark.sql("vacuum hospital_final_delta retain 168 hours dry run")
# Out:
# DataFrame[path: string]

# %% [markdown]
# part-8

# %%
daily_visits_data = [
(26,1002,201,"2024-03-14","Completed",2),
(27,1005,210,"2024-03-14","Completed",1),
(11,1011,205,"2024-03-06","Completed",3),
(20,1020,206,"2024-03-10","Completed",2),
(28,1018,203,"2024-03-15","Pending",2)
]
daily_visits_columns = [
"visit_id","patient_id","doctor_id","visit_date","visit_status","tests_count"
]
daily_visits_df = spark.createDataFrame(daily_visits_data, daily_visits_columns)

# %%
visits_df.write.format("delta").mode("overwrite").saveAsTable("target_visits_delta")

# %%
spark.read.table("target_visits_delta").show()
# Out:
# +--------+----------+---------+----------+------------+-----------+--------------------+--------------+
# |visit_id|patient_id|doctor_id|visit_date|visit_status|tests_count|estimated_total_bill|visit_priority|
# +--------+----------+---------+----------+------------+-----------+--------------------+--------------+
# |       1|      1001|      201|2024-03-01|   Completed|          2|                2002|          High|
# |       2|      1002|      202|2024-03-01|   Completed|          1|                2001|          High|
# |       3|      1003|      203|2024-03-02|   Completed|          3|                2003|          High|
# |       4|      1004|      204|2024-03-02|     Pending|          1|                2001|       Mediuim|
# |       5|      1005|      206|2024-03-03|   Completed|          2|                2002|          High|
# |       6|      1006|      205|2024-03-03|   Completed|          4|                2004|          High|
# ...

# %%
daily_visits_df.createOrReplaceTempView("daily_updates")

# %%
from delta.tables import DeltaTable
target_table=DeltaTable.forName(spark,"target_visits_delta")
source_df=daily_visits_df.withColumn("visit_date",to_date(col("visit_date"),"yyyy-MM-dd")).withColumn("estimated_total_bill",col("tests_count")+2000).withColumn("visit_priority",when(col("visit_status")=="Completed","High").when(col("visit_status")=="Pending","Mediuim").otherwise("Low"))
target_table.alias("t").merge(source_df.alias("s"),"t.visit_id=s.visit_id").whenMatchedUpdateAll().whenNotMatchedInsertAll().execute()
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]

# %%
spark.sql("select * from target_visits_delta where visit_id in (11,20)").show()
# Out:
# +--------+----------+---------+----------+------------+-----------+--------------------+--------------+
# |visit_id|patient_id|doctor_id|visit_date|visit_status|tests_count|estimated_total_bill|visit_priority|
# +--------+----------+---------+----------+------------+-----------+--------------------+--------------+
# |      20|      1020|      206|2024-03-10|   Completed|          2|                2002|          High|
# |      11|      1011|      205|2024-03-06|   Completed|          3|                2003|          High|
# +--------+----------+---------+----------+------------+-----------+--------------------+--------------+

# %%
spark.sql("select * from target_visits_delta where visit_id in (26,27,28)").show()
# Out:
# +--------+----------+---------+----------+------------+-----------+--------------------+--------------+
# |visit_id|patient_id|doctor_id|visit_date|visit_status|tests_count|estimated_total_bill|visit_priority|
# +--------+----------+---------+----------+------------+-----------+--------------------+--------------+
# |      28|      1018|      203|2024-03-15|     Pending|          2|                2002|       Mediuim|
# |      26|      1002|      201|2024-03-14|   Completed|          2|                2002|          High|
# |      27|      1005|      210|2024-03-14|   Completed|          1|                2001|          High|
# +--------+----------+---------+----------+------------+-----------+--------------------+--------------+

# %%
spark.sql("select visit_id,visit_status from target_visits_delta where visit_id in (11,20)").show()
# Out:
# +--------+------------+
# |visit_id|visit_status|
# +--------+------------+
# |      20|   Completed|
# |      11|   Completed|
# +--------+------------+

# %%
spark.sql("select * from target_visits_delta where visit_id>=26").show()
# Out:
# +--------+----------+---------+----------+------------+-----------+--------------------+--------------+
# |visit_id|patient_id|doctor_id|visit_date|visit_status|tests_count|estimated_total_bill|visit_priority|
# +--------+----------+---------+----------+------------+-----------+--------------------+--------------+
# |      28|      1018|      203|2024-03-15|     Pending|          2|                2002|       Mediuim|
# |      26|      1002|      201|2024-03-14|   Completed|          2|                2002|          High|
# |      27|      1005|      210|2024-03-14|   Completed|          1|                2001|          High|
# +--------+----------+---------+----------+------------+-----------+--------------------+--------------+

# %%
spark.sql("describe history target_visits_delta").show()
# Out:
# +-------+-------------------+---------------+--------------------+--------------------+--------------------+----+------------------+-----------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# |version|          timestamp|         userId|            userName|           operation| operationParameters| job|          notebook|queryHistoryStatementId|           clusterId|readVersion|   isolationLevel|isBlindAppend|    operationMetrics|userMetadata|          engineInfo|
# +-------+-------------------+---------------+--------------------+--------------------+--------------------+----+------------------+-----------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# ...

# %% [markdown]
# MERGE is used for incremental loads because it can update existing records and insert new records in a single operation without reloading the full dataset.

# %% [markdown]
# PART-9 DONE IN ANOTHER file..

# %% [markdown]
# PART-10 PIPELINE

# %%
spark.sql("show tables").show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | default|     bronze_hospital|      false|
# | default|  bronze_hospital_v2|      false|
# | default|bronze_patient_vi...|      false|
# | default|bronze_patient_vi...|      false|
# | default| bronze_sales_inline|      false|
# | default|completed_visits_...|      false|
# | default|           customers|      false|
# | default| customers_delta_sql|      false|
# | default|    ecommerce_orders|      false|
# | default|   gold_city_revenue|      false|
# | default|gold_city_sales_s...|      false|
# | default|gold_department_s...|      false|
# | default|gold_hospital_sum...|      false|
# | default|    gold_hospital_v2|      false|
# | default|gold_specializati...|      false|
# | default|  hospital_analytics|      false|
# | default| hospital_clean_data|      false|
# | default| hospital_data_delta|      false|
# ...
