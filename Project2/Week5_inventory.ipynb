# %%
import pandas as pd

df=pd.read_csv("master_inventory_view.csv")

reorder=df[df['reorder_flag']=="Reorder Immediately"]

print("===== DAILY REORDER REPORT =====")
print(reorder)

reorder.to_csv("daily_reorder_report.csv",index=False)

print("daily_reorder_report.csv exported successfully")

from google.colab import files
files.download("daily_reorder_report.csv")
# Out:
# ===== DAILY REORDER REPORT =====
#    product_id product_name  reorder_level  current_stock  stock_status  \
# 1           2        Mouse             20             15  Understocked
# 3           4        Chair              5              2  Understocked
#
#           reorder_flag
# 1  Reorder Immediately
# 3  Reorder Immediately
# daily_reorder_report.csv exported successfully
